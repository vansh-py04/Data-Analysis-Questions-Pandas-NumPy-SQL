# %% [markdown]
# # 450+ Practice Questions From Pandas, NumPy, and SQL.

# %% [markdown]
# Author: **Avi Chawla**
#
# LinkedIn: https://www.linkedin.com/in/avi-chawla/
#
# Read my newsletter here: https://www.blog.dailydoseofds.com/

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook has been created for you to practice three of the most common tools used in building any machine learning or data science applications, i.e., Pandas, NumPy, and SQL!

# %% [markdown]
# The practice questions provided will serve as a great resource for those who are looking to familiarize themselves with some of the most common functions used in these tools.

# %% [markdown]
# Appropriate descriptions have been provided for all the questions in this entire exercise which will help you navigate through this exercise easily. If a dataset is to be loaded in the python environment, that has also been provided for you. You can find it on the right panel in the Files section. Do NOT delete any of the files/folders listed there.

# %% [markdown]
# The whole exercise has been divided into nine separate notebooks. Below are the links to all the other notebooks for you to jump from one notebook to another:

# %% [markdown]
# - **Pandas**
#
# 1. Pandas Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-1-d693ac55-6455-40cf-ae34-867c6a02014e/notebook/6449493c84734151b11f4b6871f045d2#99f75bf946d04b9bb1daa9e14c2cfea9)
# 2. Pandas Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-dataset-7e3b6755-5d4b-464b-9b75-9c84667ae3bd/notebook/notebook-0de50f3b70834570b13b651dde44c491)
#
# 3. Pandas Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/notebook/notebook-78e3faf901da4f14881ef24e41c80bf6) **(This Notebook)**
#
# 4. Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/notebook/notebook-134ac20c38ef45e5a4432abd638e6c2e)
#
# - **NumPy**
#
# 1. NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/notebook/notebook-07232b5ebafe49b198a9c55c553414f1)
#
# 2. NumPy Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-2-4456411e-2ddd-426d-8027-4881080027db/notebook/notebook-988aba30f33a45a3861adc4f6a6f338c)
#
# 3. NumPy Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-3-e6587114-b580-4249-b599-540de859e603/notebook/notebook-bb52759ea3f542eaaed9958b5df9c34b)
#
# - **SQL**
#
# 1. SQL Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-1-eac9d782-a9b1-4e84-a1f9-af14080a6121/notebook/notebook-697f04297c664d02901db0f85431512e)
#
# 2. SQL Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-2-1914b214-be03-44a1-be63-ad99e98be639/notebook/notebook-e549236b988c42a5b53126a7ebb98127)

# %% [markdown]
# ## How to use this notebook?

# %% [markdown]
# At the top right corner, you will find a Duplicate button. This will allow you to create a unique notebook for your own practice and write solutions to the question listed in this notebook.

# %% [markdown]
# If you face any issues or have any feedback, feel free to reach out to me (Avi Chawla) either on Linkedin: https://www.linkedin.com/in/avi-chawla/ or write an email to avi@dailydoseofds[dot]com.

# %% [markdown]
# Let's begin 🚀!

# %% [markdown]
# # Pandas Notebook 3

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_dataset.csv")
df.head()
# Out:
#              Name                  Company_Name
# 0  Spencer Adkins                James and Sons  \
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City
# 0                          Equities trader     New Russellton  \
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8

# %% [markdown]
# ### 91. What is the ratio of total full-time employees to Interns?

# %%
sum(df["Employment_Status"]=="Full Time")/sum(df["Employment_Status"]=="Intern")
# Out:
# 4.0008334722453744

# %% [markdown]
# ### 92. Starting from the first record, print every third record in the DataFrame.

# %% [markdown]
# Print 1st row, then 4th, 7th, 10th, and so on...

# %%
df.iloc[1::3]
# Out:
#                    Name              Company_Name
# 1          Julie Morton             Nichols-James  \
# 4         Theresa Owens  Baker, Allen and Edwards
# 7           Vicki Beard              Matthews Inc
# 10      Victoria Sutton   White, Mcclain and Cobb
# 13          David Duran             Nichols-James
# ...                 ...                       ...
# 299986      Chelsea Lee               Andrade LLC
# 299989   Deborah Berger            James and Sons
# 299992  Steven Thornton  Baker, Allen and Edwards
# 299995       Nancy Neal          Bullock-Carrillo
# 299998    Lindsey Keith             Nichols-James
#
#                              Employee_Job_Title      Employee_City
# 1       Diplomatic Services operational officer  North Melissafurt  \
# 4                           Production engineer          Whiteside
# 7       Diplomatic Services operational officer        Kristaburgh
# 10                              Naval architect          Whiteside
# 13                 Investment banker, corporate     New Russellton
# ...                                         ...                ...
# 299986             Investment banker, corporate           Wardfort
# 299989        Sales promotion account executive   New Cindychester
# 299992                          Patent examiner         Aliciafort
# 299995                              Optometrist  North Melissafurt
# 299998                                     Make       Whitakerbury
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 1       Marshall Islands           589090         Full Time              4.3
# 4               Dominica           523499         Full Time              4.8
# 7         Western Sahara           777000         Full Time              3.3
# 10                Poland           656260         Full Time              4.9
# 13               Georgia           910210         Full Time              4.9
# ...                  ...              ...               ...              ...
# 299986       Switzerland            88410         Full Time              4.4
# 299989             Malta           285660         Full Time              3.1
# 299992             Benin            60240         Full Time              4.3
# 299995             Samoa            99670            Intern              3.3
# 299998    Western Sahara           257240         Full Time              2.4
#
# [100000 rows x 8 columns]

# %% [markdown]
# ### 93. Find the average salary for every company.

# %%
df.groupby("Company_Name")[["Employee_Salary"]].mean().reset_index()
# Out:
#                            Company  Employee_Salary
# 0                      Andrade LLC    497237.159385
# 1         Baker, Allen and Edwards    498032.358445
# 2                 Bullock-Carrillo    499603.804865
# 3   Campos, Reynolds and Mccormick    503528.982687
# 4                   James and Sons    503581.015754
# 5     Johnston, Fleming and Tanner    500579.128010
# 6                Marshall-Holloway    502314.169445
# 7                     Matthews Inc    501640.159488
# 8                        Nelson-Li    500569.824558
# 9                    Nichols-James    497881.232334
# 10                       Scott Inc    500491.809024
# 11                    Taylor-Ramos    498747.292516
# 12                  Thomas-Spencer    499350.850164
# 13      Wallace, Smith and Shepard    500807.608810
# 14         White, Mcclain and Cobb    499083.493806

# %% [markdown]
# ### 94. Find the average rating for every company.

# %%
df.groupby("Company_Name")[["Employee_Rating"]].mean().reset_index()
# Out:
#                       Company_Name  Employee_Rating
# 0                      Andrade LLC         2.498218
# 1         Baker, Allen and Edwards         2.504795
# 2                 Bullock-Carrillo         2.502014
# 3   Campos, Reynolds and Mccormick         2.506288
# 4                   James and Sons         2.505023
# 5     Johnston, Fleming and Tanner         2.513159
# 6                Marshall-Holloway         2.504900
# 7                     Matthews Inc         2.525454
# 8                        Nelson-Li         2.504649
# 9                    Nichols-James         2.488554
# 10                       Scott Inc         2.515993
# 11                    Taylor-Ramos         2.513150
# 12                  Thomas-Spencer         2.505114
# 13      Wallace, Smith and Shepard         2.497402
# 14         White, Mcclain and Cobb         2.504047

# %% [markdown]
# ### 95. Find the average salary and average rating for every company in a single line.

# %%
df.groupby("Company_Name")[["Employee_Salary","Employee_Rating"]].mean().reset_index()
# Out:
#                       Company_Name  Employee_Salary  Employee_Rating
# 0                      Andrade LLC    497237.159385         2.498218
# 1         Baker, Allen and Edwards    498032.358445         2.504795
# 2                 Bullock-Carrillo    499603.804865         2.502014
# 3   Campos, Reynolds and Mccormick    503528.982687         2.506288
# 4                   James and Sons    503581.015754         2.505023
# 5     Johnston, Fleming and Tanner    500579.128010         2.513159
# 6                Marshall-Holloway    502314.169445         2.504900
# 7                     Matthews Inc    501640.159488         2.525454
# 8                        Nelson-Li    500569.824558         2.504649
# 9                    Nichols-James    497881.232334         2.488554
# 10                       Scott Inc    500491.809024         2.515993
# 11                    Taylor-Ramos    498747.292516         2.513150
# 12                  Thomas-Spencer    499350.850164         2.505114
# 13      Wallace, Smith and Shepard    500807.608810         2.497402
# 14         White, Mcclain and Cobb    499083.493806         2.504047

# %% [markdown]
# ### 96. Find the number of unique Employee_City corresponding to every Company_Name.

# %%
df.groupby("Company_Name")[["Employee_City"]].nunique().reset_index()
# Out:
#                       Company_Name  Employee_City
# 0                      Andrade LLC             10
# 1         Baker, Allen and Edwards             10
# 2                 Bullock-Carrillo             10
# 3   Campos, Reynolds and Mccormick             10
# 4                   James and Sons             10
# 5     Johnston, Fleming and Tanner             10
# 6                Marshall-Holloway             10
# 7                     Matthews Inc             10
# 8                        Nelson-Li             10
# 9                    Nichols-James             10
# 10                       Scott Inc             10
# 11                    Taylor-Ramos             10
# 12                  Thomas-Spencer             10
# 13      Wallace, Smith and Shepard             10
# 14         White, Mcclain and Cobb             10

# %% [markdown]
# ### 98. Print the number of full-time and intern employees for every company

# %%
df.groupby("Company_Name")[["Employment_Status"]].value_counts()
# Out:
# Company_Name                    Employment_Status
# Andrade LLC                     Full Time            15964
#                                 Intern                4019
# Baker, Allen and Edwards        Full Time            16118
#                                 Intern                3966
# Bullock-Carrillo                Full Time            16135
#                                 Intern                3928
# Campos, Reynolds and Mccormick  Full Time            15930
#                                 Intern                3997
# James and Sons                  Full Time            15888
#                                 Intern                3980
# Johnston, Fleming and Tanner    Full Time            15832
#                                 Intern                3979
# Marshall-Holloway               Full Time            15871
#                                 Intern                3988
# Matthews Inc                    Full Time            16082
#                                 Intern                4001
# Nelson-Li                       Full Time            16027
#                                 Intern                4105
# Nichols-James                   Full Time            15872
#                                 Intern                4039
# Scott Inc                       Full Time            16396
#                                 Intern                3994
# Taylor-Ramos                    Full Time            16086
#                                 Intern                4036
# Thomas-Spencer                  Full Time            16037
#                                 Intern                4105
# Wallace, Smith and Shepard      Full Time            15467
#                                 Intern                3897
# White, Mcclain and Cobb         Full Time            16305
#                                 Intern                3956
# Name: count, dtype: int64

# %% [markdown]
# ### 99. Print the job title with the most employees.

# %%
df["Employee_Job_Title"].value_counts().idxmax()
# Out:
# 'Diplomatic Services operational officer'

# %% [markdown]
# ### 100. Print the job title with the most employees corresponding to every company.

# %%
df.groupby("Company_Name")["Employee_Job_Title"].agg(lambda x: x.value_counts().idxmax()).reset_index()
# Out:
#                       Company_Name                       Employee_Job_Title
# 0                      Andrade LLC  Diplomatic Services operational officer
# 1         Baker, Allen and Edwards  Diplomatic Services operational officer
# 2                 Bullock-Carrillo  Diplomatic Services operational officer
# 3   Campos, Reynolds and Mccormick  Diplomatic Services operational officer
# 4                   James and Sons  Diplomatic Services operational officer
# 5     Johnston, Fleming and Tanner  Diplomatic Services operational officer
# 6                Marshall-Holloway  Diplomatic Services operational officer
# 7                     Matthews Inc  Diplomatic Services operational officer
# 8                        Nelson-Li  Diplomatic Services operational officer
# 9                    Nichols-James  Diplomatic Services operational officer
# 10                       Scott Inc  Diplomatic Services operational officer
# 11                    Taylor-Ramos  Diplomatic Services operational officer
# 12                  Thomas-Spencer  Diplomatic Services operational officer
# 13      Wallace, Smith and Shepard  Diplomatic Services operational officer
# 14         White, Mcclain and Cobb  Diplomatic Services operational officer

# %% [markdown]
# ### 101. Find the average salary for corresponding to every value of 'Employment_Status'

# %%
df.groupby("Employment_Status")["Employee_Salary"].mean().reset_index()
# Out:
#   Employment_Status  Employee_Salary
# 0         Full Time    500202.359368
# 1            Intern    500311.619370

# %% [markdown]
# ### 102. Print the index corresponding to the maximum Employee_Salary

# %%
df["Employee_Salary"].idxmax()
# Out:
# 70356

# %% [markdown]
# ### 103. How many unique firstnames exist in the dataset?

# %%
len(df["Name"].str.split().str[0].unique())
# Out:
# 690

# %% [markdown]
# ### 104. How many unique lastnames exist in the dataset?

# %%
df["Name"].str.split().str[-1].nunique()
# Out:
# 1000

# %% [markdown]
# ### 105. How many unique firstnames exist in the dataset for every company?

# %%
df.groupby("Company_Name")["Name"].agg(lambda x : x.str.split().str[0].nunique())
# Out:
# Company_Name
# Andrade LLC                       686
# Baker, Allen and Edwards          686
# Bullock-Carrillo                  687
# Campos, Reynolds and Mccormick    682
# James and Sons                    683
# Johnston, Fleming and Tanner      683
# Marshall-Holloway                 686
# Matthews Inc                      687
# Nelson-Li                         683
# Nichols-James                     684
# Scott Inc                         689
# Taylor-Ramos                      689
# Thomas-Spencer                    687
# Wallace, Smith and Shepard        681
# White, Mcclain and Cobb           686
# Name: Name, dtype: int64

# %% [markdown]
# ### 106. Are there any rows for the employee name 'Michael Edward'? Print True or False

# %%
(df["Name"]=="Michael Edward").any()
# Out:
# False

# %% [markdown]
# ### 107. Check if the substring 'Michael Edward' appears in the Name column or not.

# %%
(df["Name"].str.contains("Michael Edward",na=False)).any()
# Out:
# True

# %% [markdown]
# ### 108. How many unique Job titles start with the substring 'Pr' (case-sensitive matching)

# %%
df[df["Employee_Job_Title"].str.startswith("Pr")]["Employee_Job_Title"].nunique()
# Out:
# 1

# %% [markdown]
# ### 109. How many unique Job titles start with the substring 'Pr' (case-insensitive matching)

# %%
df.loc[df["Employee_Job_Title"].str.startswith("Pr"), "Employee_Job_Title"].nunique()
# Out:
# 1

# %% [markdown]
# ### 109. How many records are there whose Country end with the substring 'urt' (case-insensitive matching)

# %%
df[df["Employee_Country"].str.endswith("urt")]["Employee_Country"].nunique()
# Out:
# 0

# %% [markdown]
# ### 110. Print the number of records whose company name contains the substring 'LL' (case-insensitive).

# %%
df[df["Company_Name"].str.contains("LL")]["Company_Name"].nunique()
# Out:
# 1

# %% [markdown]
# ### 111. Select the first row corresponding to every company in the dataframe

# %%
df.drop_duplicates("Company_Name")
# Out:
#                   Name                    Company_Name
# 0       Spencer Adkins                  James and Sons  \
# 1         Julie Morton                   Nichols-James
# 2         Matthew Hall                       Scott Inc
# 3           Brad Scott    Johnston, Fleming and Tanner
# 4        Theresa Owens        Baker, Allen and Edwards
# 5        Vanessa Allen                     Andrade LLC
# 7          Vicki Beard                    Matthews Inc
# 8          Lisa French                    Taylor-Ramos
# 9      Michael Edwards  Campos, Reynolds and Mccormick
# 10     Victoria Sutton         White, Mcclain and Cobb
# 17           Gail Rose                  Thomas-Spencer
# 18        Carrie Woods                Bullock-Carrillo
# 25      David Phillips               Marshall-Holloway
# 45        Ronald Clark      Wallace, Smith and Shepard
# 61  Micheal Fitzgerald                       Nelson-Li
#
#                          Employee_Job_Title      Employee_City
# 0                           Equities trader     New Russellton  \
# 1   Diplomatic Services operational officer  North Melissafurt
# 2                Regulatory affairs officer           Wardfort
# 3                       Production engineer     West Jamesview
# 4                       Production engineer          Whiteside
# 5                                      Make       Ricardomouth
# 7   Diplomatic Services operational officer        Kristaburgh
# 8                 Radiographer, therapeutic     West Jamesview
# 9                                Ergonomist   New Cindychester
# 10                          Naval architect          Whiteside
# 17                          Patent examiner       Whitakerbury
# 18                               Ergonomist     New Russellton
# 25                Radiographer, therapeutic        Kristaburgh
# 45               Regulatory affairs officer  North Melissafurt
# 61  Diplomatic Services operational officer       Whitakerbury
#
#                     Employee_Country  Employee_Salary Employment_Status
# 0              Palestinian Territory           321520         Full Time  \
# 1                   Marshall Islands           589090         Full Time
# 2                           Anguilla           630890         Full Time
# 3               Syrian Arab Republic           116400         Full Time
# 4                           Dominica           523499         Full Time
# 5                               Mali           850140         Full Time
# 7                     Western Sahara           777000         Full Time
# 8                             Kuwait           870580         Full Time
# 9   Lao People's Democratic Republic           516950         Full Time
# 10                            Poland           656260         Full Time
# 17                           Finland           178570         Full Time
# 18                             Gabon           985290         Full Time
# 25            British Virgin Islands            58800         Full Time
# 45                             Palau           914110         Full Time
# 61                       Switzerland           796690         Full Time
#
#     Employee_Rating
# 0               3.9
# 1               4.3
# 2               3.1
# 3               3.1
# 4               4.8
# 5               2.6
# 7               3.3
# 8               1.3
# 9               2.3
# 10              4.9
# 17              1.9
# 18              2.4
# 25              0.6
# 45              3.2
# 61              4.1

# %% [markdown]
# ### 112. Select the last row corresponding to every company in the dataframe

# %%
df.groupby("Company_Name").last().reset_index()
# Out:
#                       Company_Name               Name
# 0                      Andrade LLC        Chelsea Lee  \
# 1         Baker, Allen and Edwards    Steven Thornton
# 2                 Bullock-Carrillo         Nancy Neal
# 3   Campos, Reynolds and Mccormick         Lori Chang
# 4                   James and Sons      Karen Delgado
# 5     Johnston, Fleming and Tanner     Michele Butler
# 6                Marshall-Holloway        Sarah Parks
# 7                     Matthews Inc      Melissa Blair
# 8                        Nelson-Li      Chase Stevens
# 9                    Nichols-James      Lindsey Keith
# 10                       Scott Inc  William Rodriguez
# 11                    Taylor-Ramos   Elizabeth Carter
# 12                  Thomas-Spencer     William Jensen
# 13      Wallace, Smith and Shepard      Monica Bender
# 14         White, Mcclain and Cobb      Kelly Bennett
#
#                    Employee_Job_Title      Employee_City
# 0        Investment banker, corporate           Wardfort  \
# 1                     Patent examiner         Aliciafort
# 2                         Optometrist  North Melissafurt
# 3                     Naval architect   New Cindychester
# 4                             Actuary     New Russellton
# 5                       Administrator         Aliciafort
# 6                          Ergonomist   New Cindychester
# 7           Radiographer, therapeutic          Whiteside
# 8                      Energy manager       Whitakerbury
# 9                                Make       Whitakerbury
# 10                         Ergonomist          Whiteside
# 11         Regulatory affairs officer     West Jamesview
# 12  Sales promotion account executive  North Melissafurt
# 13                Production engineer   New Cindychester
# 14          Radiographer, therapeutic           Wardfort
#
#                     Employee_Country  Employee_Salary Employment_Status
# 0                        Switzerland            88410         Full Time  \
# 1                              Benin            60240         Full Time
# 2                              Samoa            99670            Intern
# 3                              Japan           723370            Intern
# 4                     United Kingdom           575770            Intern
# 5                               Cuba           949580            Intern
# 6             Libyan Arab Jamahiriya           793670            Intern
# 7   Lao People's Democratic Republic           455410         Full Time
# 8           Northern Mariana Islands           590590         Full Time
# 9                     Western Sahara           257240         Full Time
# 10                       New Zealand           214400         Full Time
# 11                      Turkmenistan           629680         Full Time
# 12                Russian Federation           637780            Intern
# 13                        Bangladesh           852660         Full Time
# 14                              Fiji           182270         Full Time
#
#     Employee_Rating
# 0               4.4
# 1               4.3
# 2               3.3
# 3               4.0
# 4               3.3
# 5               2.6
# 6               2.0
# 7               1.3
# 8               2.6
# 9               2.4
# 10              1.5
# 11              4.0
# 12              1.6
# 13              3.0
# 14              3.6

# %% [markdown]
# ### 113. Reset the index of the dataframe inplace and delete the older index values.

# %%
df.reset_index(inplace=True,drop=True)
df
# Out:
#                   Name                  Company_Name
# 0       Spencer Adkins                James and Sons  \
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City
# 0                               Equities trader     New Russellton  \
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status
# 0       Palestinian Territory           321520         Full Time  \
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 114. Print the type of the DataFrame object.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 115. Add a new row at the bottom of the DataFrame.

# %%
new_row = ["Chris Anders", "Scott Inc", "Production engineer", "Wardfort", "Anguilla", 343930, "Full Time", 3.3]

nr = pd.DataFrame([new_row],columns=df.columns)
df = pd.concat([df,nr],ignore_index=True)

df.tail()
# Out:
#                   Name                  Company_Name   Employee_Job_Title
# 299996  Michele Butler  Johnston, Fleming and Tanner        Administrator  \
# 299997     Lynn Wilson                 Nichols-James        Administrator
# 299998   Lindsey Keith                 Nichols-James                 Make
# 299999   Karen Delgado                James and Sons              Actuary
# 300000    Chris Anders                     Scott Inc  Production engineer
#
#            Employee_City Employee_Country  Employee_Salary Employment_Status
# 299996        Aliciafort             Cuba           949580            Intern  \
# 299997  New Cindychester          Bolivia           802830         Full Time
# 299998      Whitakerbury   Western Sahara           257240         Full Time
# 299999    New Russellton   United Kingdom           575770            Intern
# 300000          Wardfort         Anguilla           343930         Full Time
#
#         Employee_Rating
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
# 300000              3.3

# %% [markdown]
# ### 116. Print the new shape of the DataFrame.

# %%
df.shape
# Out:
# (300001, 8)

# %% [markdown]
# ### 117. Add a new column "Employee_Rating_New" which should be as follows:

# %% [markdown]
# Employee_Rating_New = max(1.5, 2*Employee_Rating - 3)

# %%
df["Employee_Rating_New"] = df["Employee_Rating"].apply(lambda x : max(1.5,2*x-3))

df.head()
# Out:
#              Name                  Company_Name
# 0  Spencer Adkins                James and Sons  \
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City
# 0                          Equities trader     New Russellton  \
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9  \
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8
#
#    Employee_Rating_New
# 0                  4.8
# 1                  5.6
# 2                  3.2
# 3                  3.2
# 4                  6.6

# %% [markdown]
# ### 118. Convert the entire DataFrame to a list of lists. Do NOT overwrite to the current dataframe object.

# %%
df_list = df.values.tolist()

df_list
# Out:
# [['Spencer Adkins',
#   'James and Sons',
#   'Equities trader',
#   'New Russellton',
#   'Palestinian Territory',
#   321520,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Julie Morton',
#   'Nichols-James',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'Marshall Islands',
#   589090,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Matthew Hall',
#   'Scott Inc',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Anguilla',
#   630890,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Brad Scott',
#   'Johnston, Fleming and Tanner',
#   'Production engineer',
#   'West Jamesview',
#   'Syrian Arab Republic',
#   116400,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Theresa Owens',
#   'Baker, Allen and Edwards',
#   'Production engineer',
#   'Whiteside',
#   'Dominica',
#   523499,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Vanessa Allen',
#   'Andrade LLC',
#   'Make',
#   'Ricardomouth',
#   'Mali',
#   850140,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Kelly Brown',
#   'Andrade LLC',
#   'Naval architect',
#   'Wardfort',
#   'Aruba',
#   711410,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Vicki Beard',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Western Sahara',
#   777000,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Lisa French',
#   'Taylor-Ramos',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Kuwait',
#   870580,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Michael Edwards',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'New Cindychester',
#   "Lao People's Democratic Republic",
#   516950,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Victoria Sutton',
#   'White, Mcclain and Cobb',
#   'Naval architect',
#   'Whiteside',
#   'Poland',
#   656260,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Timothy Johnson',
#   'Baker, Allen and Edwards',
#   'Regulatory affairs officer',
#   'Ricardomouth',
#   'Georgia',
#   503610,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Tiffany Galvan',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Niger',
#   786430,
#   'Intern',
#   3.6,
#   4.2],
#  ['David Duran',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Georgia',
#   910210,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Julie Cook',
#   'Matthews Inc',
#   'Equities trader',
#   'New Russellton',
#   'Puerto Rico',
#   328860,
#   'Full Time',
#   4.8,
#   6.6],
#  ['David Massey',
#   'Johnston, Fleming and Tanner',
#   'Radiographer, therapeutic',
#   'Ricardomouth',
#   'Somalia',
#   581490,
#   'Intern',
#   3.7,
#   4.4],
#  ['Taylor Summers',
#   'Campos, Reynolds and Mccormick',
#   'Naval architect',
#   'North Melissafurt',
#   'Falkland Islands (Malvinas)',
#   280650,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Gail Rose',
#   'Thomas-Spencer',
#   'Patent examiner',
#   'Whitakerbury',
#   'Finland',
#   178570,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Carrie Woods',
#   'Bullock-Carrillo',
#   'Ergonomist',
#   'New Russellton',
#   'Gabon',
#   985290,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Christopher Kim',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Serbia',
#   242300,
#   'Intern',
#   1.6,
#   1.5],
#  ['Brian Swanson',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Libyan Arab Jamahiriya',
#   262670,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Ashley Hess',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Netherlands',
#   2990,
#   'Intern',
#   1.5,
#   1.5],
#  ['Carlos Lindsey',
#   'Nichols-James',
#   'Patent examiner',
#   'Kristaburgh',
#   'Jersey',
#   629640,
#   'Intern',
#   0.3,
#   1.5],
#  ['Daniel Medina',
#   'Matthews Inc',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Antarctica (the territory South of 60 deg S)',
#   511650,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Michael Williams',
#   'Johnston, Fleming and Tanner',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Malawi',
#   705500,
#   'Intern',
#   0.7,
#   1.5],
#  ['David Phillips',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'British Virgin Islands',
#   58800,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Donna Rodriguez',
#   'Thomas-Spencer',
#   'Sales promotion account executive',
#   'Whiteside',
#   'Guam',
#   622920,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Courtney Cherry',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'Wardfort',
#   'Puerto Rico',
#   388970,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Kim Reynolds',
#   'Marshall-Holloway',
#   'Actuary',
#   'West Jamesview',
#   'Faroe Islands',
#   794450,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Rodney Little',
#   'James and Sons',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Indonesia',
#   846180,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Melissa Wood',
#   'Thomas-Spencer',
#   'Administrator',
#   'New Russellton',
#   'France',
#   836160,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Antonio Gomez',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Anguilla',
#   904930,
#   'Intern',
#   1.3,
#   1.5],
#  ['Gary Jackson',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'Aliciafort',
#   'Macedonia',
#   141250,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Selena Moyer',
#   'Baker, Allen and Edwards',
#   'Trading standards officer',
#   'North Melissafurt',
#   'Belize',
#   234370,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Sherry Charles',
#   'Scott Inc',
#   'Garment/textile technologist',
#   'West Jamesview',
#   'El Salvador',
#   787030,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Kevin Flores',
#   'Scott Inc',
#   'Radiographer, therapeutic',
#   'New Cindychester',
#   'Congo',
#   421860,
#   'Full Time',
#   1.3,
#   1.5],
#  ['James Cole',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Norfolk Island',
#   654770,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Deborah Cantu',
#   'Taylor-Ramos',
#   'Production engineer',
#   'New Russellton',
#   'Kiribati',
#   92600,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Victor Miller',
#   'Thomas-Spencer',
#   'Patent examiner',
#   'New Russellton',
#   'France',
#   560730,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Jessica Reyes',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'Botswana',
#   667490,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Steven Cole',
#   'Marshall-Holloway',
#   'Retail merchandiser',
#   'Kristaburgh',
#   'Nicaragua',
#   981230,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Cassie Murray',
#   'Scott Inc',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Poland',
#   200500,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Nancy Wright',
#   'Johnston, Fleming and Tanner',
#   'Actuary',
#   'Ricardomouth',
#   'Palau',
#   916600,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Hannah Taylor',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'Whiteside',
#   'Western Sahara',
#   251230,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Kathleen Franco',
#   'Johnston, Fleming and Tanner',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Bolivia',
#   185270,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Ronald Clark',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Palau',
#   914110,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Francis Carter',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Singapore',
#   780840,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Jessica Alvarado',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'Greenland',
#   184410,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Shannon Wiggins',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Whiteside',
#   'Suriname',
#   880350,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Gerald Santiago',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'El Salvador',
#   873320,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Ralph Taylor',
#   'James and Sons',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Tuvalu',
#   482270,
#   'Intern',
#   1.9,
#   1.5],
#  ['Katherine Carr',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'New Russellton',
#   'Estonia',
#   610870,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Brian Scott',
#   'Thomas-Spencer',
#   'Energy manager',
#   'Ricardomouth',
#   'Portugal',
#   616430,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Robert Kelly',
#   'Wallace, Smith and Shepard',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Yemen',
#   219120,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Sydney Suarez',
#   'Matthews Inc',
#   'Make',
#   'Aliciafort',
#   'American Samoa',
#   720620,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Amanda Roth',
#   'Taylor-Ramos',
#   'Administrator',
#   'North Melissafurt',
#   'Macedonia',
#   437720,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Gavin Wise',
#   'Marshall-Holloway',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'Netherlands Antilles',
#   624990,
#   'Intern',
#   3.1,
#   3.2],
#  ['Joseph Anderson',
#   'Bullock-Carrillo',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Bhutan',
#   402290,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Robert Villanueva',
#   'Bullock-Carrillo',
#   'Make',
#   'North Melissafurt',
#   'Guyana',
#   440700,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Paul Cox',
#   'Thomas-Spencer',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'France',
#   598930,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Jessica Stewart',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'Whitakerbury',
#   'Kiribati',
#   852150,
#   'Intern',
#   3.9,
#   4.8],
#  ['Micheal Fitzgerald',
#   'Nelson-Li',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Switzerland',
#   796690,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Thomas Wilson',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'New Caledonia',
#   244960,
#   'Intern',
#   3.4,
#   3.8],
#  ['George Davidson',
#   'Marshall-Holloway',
#   'Optometrist',
#   'New Cindychester',
#   'Zimbabwe',
#   425390,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Nathan Santiago',
#   'Taylor-Ramos',
#   'Administrator',
#   'Aliciafort',
#   'Northern Mariana Islands',
#   587780,
#   'Intern',
#   3.5,
#   4.0],
#  ['Timothy Flores',
#   'White, Mcclain and Cobb',
#   'Garment/textile technologist',
#   'North Melissafurt',
#   'Romania',
#   894970,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Chad Guerrero',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'Aliciafort',
#   'Congo',
#   134810,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Claudia Morrison',
#   'Scott Inc',
#   'Administrator',
#   'Whiteside',
#   'India',
#   470350,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Justin Mclean',
#   'Nelson-Li',
#   'Retail merchandiser',
#   'Wardfort',
#   'Chad',
#   143410,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Jonathan Armstrong',
#   'Scott Inc',
#   'Trading standards officer',
#   'Aliciafort',
#   'San Marino',
#   902300,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Jason Smith',
#   'Scott Inc',
#   'Trading standards officer',
#   'Wardfort',
#   'Mozambique',
#   384980,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Daniel Charles',
#   'White, Mcclain and Cobb',
#   'Actuary',
#   'West Jamesview',
#   'Sierra Leone',
#   536990,
#   'Intern',
#   1.0,
#   1.5],
#  ['Jose Moore',
#   'Bullock-Carrillo',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Montserrat',
#   684110,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Derrick Spencer',
#   'Nelson-Li',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Holy See (Vatican City State)',
#   303900,
#   'Full Time',
#   1.5,
#   1.5],
#  ['Robert Humphrey',
#   'Marshall-Holloway',
#   'Patent examiner',
#   'Whiteside',
#   'Togo',
#   190420,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michelle Estrada',
#   'Thomas-Spencer',
#   'Energy manager',
#   'Ricardomouth',
#   'Saint Pierre and Miquelon',
#   721880,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Michael Conway',
#   'Nichols-James',
#   'Radiographer, therapeutic',
#   'Wardfort',
#   'Bangladesh',
#   187720,
#   'Full Time',
#   0.1,
#   1.5],
#  ['Lori Smith',
#   'Thomas-Spencer',
#   'Optometrist',
#   'New Cindychester',
#   'Venezuela',
#   687310,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Timothy Ramos',
#   'Nelson-Li',
#   'Equities trader',
#   'West Jamesview',
#   'Congo',
#   219690,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Bradley Montgomery',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'Iraq',
#   90650,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Jonathan Howell',
#   'Nichols-James',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Aruba',
#   711330,
#   'Full Time',
#   3.6,
#   4.2],
#  ['William Hughes',
#   'Nichols-James',
#   'Administrator',
#   'New Cindychester',
#   'Belarus',
#   16340,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Steven Costa',
#   'Taylor-Ramos',
#   'Energy manager',
#   'Wardfort',
#   'Albania',
#   314470,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Nancy Stephens',
#   'Johnston, Fleming and Tanner',
#   'Ergonomist',
#   'Kristaburgh',
#   'Taiwan',
#   430620,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Lauren Barton',
#   'Baker, Allen and Edwards',
#   'Make',
#   'New Cindychester',
#   'Pakistan',
#   789140,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Dawn Lewis',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'Whitakerbury',
#   'Suriname',
#   270840,
#   'Intern',
#   2.2,
#   1.5],
#  ['Wanda Jones',
#   'White, Mcclain and Cobb',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Libyan Arab Jamahiriya',
#   848140,
#   'Intern',
#   0.2,
#   1.5],
#  ['Brittany Graham',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Ethiopia',
#   123700,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Julie Richard',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Wardfort',
#   'Burundi',
#   222850,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Janet Bridges',
#   'Thomas-Spencer',
#   'Optometrist',
#   'Whitakerbury',
#   'Wallis and Futuna',
#   745150,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Willie Anderson',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Kristaburgh',
#   'Tuvalu',
#   268320,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Diamond Kent',
#   'Wallace, Smith and Shepard',
#   'Radiographer, therapeutic',
#   'Aliciafort',
#   'Zambia',
#   538290,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Kevin Miller',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Saint Pierre and Miquelon',
#   493800,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Sierra Brewer',
#   'Thomas-Spencer',
#   'Naval architect',
#   'New Russellton',
#   'Saint Pierre and Miquelon',
#   127940,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Natasha Harmon',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Bolivia',
#   790000,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Angela Stone',
#   'Wallace, Smith and Shepard',
#   'Actuary',
#   'New Russellton',
#   'Switzerland',
#   313250,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Anthony Weiss',
#   'Scott Inc',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Guatemala',
#   356220,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Renee Benson',
#   'Thomas-Spencer',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Thailand',
#   171820,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Elizabeth Clements',
#   'Taylor-Ramos',
#   'Administrator',
#   'Whiteside',
#   'Mauritania',
#   827360,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Jeanette Wang',
#   'Baker, Allen and Edwards',
#   'Actuary',
#   'Whiteside',
#   'New Zealand',
#   339100,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Tracy Maxwell',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Oman',
#   742410,
#   'Full Time',
#   0.5,
#   1.5],
#  ['James Alvarez',
#   'Bullock-Carrillo',
#   'Equities trader',
#   'Kristaburgh',
#   'Grenada',
#   220440,
#   'Intern',
#   2.1,
#   1.5],
#  ['Stacy Smith',
#   'Bullock-Carrillo',
#   'Patent examiner',
#   'Kristaburgh',
#   'Israel',
#   666680,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Jennifer Daniels',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'West Jamesview',
#   'Congo',
#   130740,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Jose Thompson',
#   'Scott Inc',
#   'Actuary',
#   'Whitakerbury',
#   'Sweden',
#   121110,
#   'Intern',
#   1.2,
#   1.5],
#  ['Mary Bailey',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Sierra Leone',
#   142620,
#   'Intern',
#   0.8,
#   1.5],
#  ['Susan Moses',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Aliciafort',
#   "Cote d'Ivoire",
#   196070,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Kathryn Sweeney',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'New Russellton',
#   'Madagascar',
#   489190,
#   'Intern',
#   0.3,
#   1.5],
#  ['Frank Torres',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'Whitakerbury',
#   'Sierra Leone',
#   693190,
#   'Intern',
#   2.9,
#   2.8],
#  ['James Wright',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Ricardomouth',
#   'Chad',
#   79790,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Donald Nelson',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'West Jamesview',
#   'Estonia',
#   37280,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Daniel Adams',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'San Marino',
#   339250,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Crystal Brown',
#   'Johnston, Fleming and Tanner',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'Romania',
#   919880,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Judy Roberts',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'Whitakerbury',
#   'Northern Mariana Islands',
#   45560,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Jeremiah Kelly',
#   'Scott Inc',
#   'Make',
#   'West Jamesview',
#   'Anguilla',
#   155360,
#   'Intern',
#   4.9,
#   6.800000000000001],
#  ['Gary Hernandez',
#   'Taylor-Ramos',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Solomon Islands',
#   888730,
#   'Intern',
#   2.5,
#   2.0],
#  ['Annette Saunders',
#   'Marshall-Holloway',
#   'Ergonomist',
#   'New Cindychester',
#   'Monaco',
#   684380,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Jacob Cunningham',
#   'James and Sons',
#   'Patent examiner',
#   'Aliciafort',
#   'Latvia',
#   876760,
#   'Intern',
#   3.8,
#   4.6],
#  ['Stacey Ellison',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Hungary',
#   393820,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Jason Parrish',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Aliciafort',
#   "Cote d'Ivoire",
#   581130,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Pamela Martinez',
#   'James and Sons',
#   'Garment/textile technologist',
#   'Whiteside',
#   'Dominican Republic',
#   587360,
#   'Intern',
#   3.6,
#   4.2],
#  ['Christine Harrison',
#   'James and Sons',
#   'Trading standards officer',
#   'West Jamesview',
#   'Namibia',
#   684820,
#   'Intern',
#   1.1,
#   1.5],
#  ['Joanna Mclean',
#   'Andrade LLC',
#   'Actuary',
#   'North Melissafurt',
#   'Kuwait',
#   108980,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Kyle Rogers',
#   'Baker, Allen and Edwards',
#   'Patent examiner',
#   'Whitakerbury',
#   'Tuvalu',
#   931250,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Joshua Huffman',
#   'James and Sons',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Cook Islands',
#   694760,
#   'Full Time',
#   5.0,
#   7.0],
#  ['Michael Gonzalez',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'West Jamesview',
#   'Sweden',
#   302110,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Michael Morgan',
#   'Wallace, Smith and Shepard',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Saint Kitts and Nevis',
#   178380,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Matthew Wright',
#   'Bullock-Carrillo',
#   'Energy manager',
#   'Whiteside',
#   'El Salvador',
#   626340,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Courtney Schneider',
#   'Nichols-James',
#   'Regulatory affairs officer',
#   'Whitakerbury',
#   'Sri Lanka',
#   750440,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Connie Coleman',
#   'Andrade LLC',
#   'Optometrist',
#   'Kristaburgh',
#   'Indonesia',
#   899260,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Brandon Casey',
#   'Wallace, Smith and Shepard',
#   'Make',
#   'New Cindychester',
#   'Sudan',
#   590560,
#   'Intern',
#   0.1,
#   1.5],
#  ['Tina Jenkins',
#   'Scott Inc',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'Malaysia',
#   100420,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Trevor Wilson',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Aliciafort',
#   'Andorra',
#   661420,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Morgan Shaw',
#   'Matthews Inc',
#   'Patent examiner',
#   'Whiteside',
#   'Egypt',
#   523320,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Angela Hatfield',
#   'Campos, Reynolds and Mccormick',
#   'Regulatory affairs officer',
#   'Wardfort',
#   'Turkey',
#   989380,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Alicia Bell',
#   'Wallace, Smith and Shepard',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Martinique',
#   832520,
#   'Intern',
#   2.5,
#   2.0],
#  ['Victor Sandoval',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   "Cote d'Ivoire",
#   819610,
#   'Intern',
#   0.5,
#   1.5],
#  ['Jennifer Smith',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Cuba',
#   202010,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Matthew Perez',
#   'White, Mcclain and Cobb',
#   'Optometrist',
#   'New Russellton',
#   'Western Sahara',
#   711310,
#   'Intern',
#   4.4,
#   5.800000000000001],
#  ['Michael Garcia',
#   'James and Sons',
#   'Equities trader',
#   'Kristaburgh',
#   'Lithuania',
#   729250,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Joseph Johnson',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Whitakerbury',
#   'France',
#   993550,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Stephen Alvarado',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'New Cindychester',
#   'Syrian Arab Republic',
#   462080,
#   'Intern',
#   0.5,
#   1.5],
#  ['Michaela Hawkins',
#   'Johnston, Fleming and Tanner',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Greenland',
#   676440,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Sabrina Salinas',
#   'Nichols-James',
#   'Optometrist',
#   'West Jamesview',
#   'Luxembourg',
#   704190,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Linda Kelley',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'Whitakerbury',
#   'Belarus',
#   202350,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Shelby Moore',
#   'Bullock-Carrillo',
#   'Retail merchandiser',
#   'Wardfort',
#   'Nauru',
#   250210,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Christopher Le',
#   'Taylor-Ramos',
#   'Equities trader',
#   'North Melissafurt',
#   'Djibouti',
#   647170,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Raymond Nguyen',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'West Jamesview',
#   'Fiji',
#   565500,
#   'Intern',
#   1.4,
#   1.5],
#  ['Christopher Gibson',
#   'Wallace, Smith and Shepard',
#   'Administrator',
#   'Whitakerbury',
#   'Cayman Islands',
#   754000,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Jeremy Miller',
#   'Thomas-Spencer',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Norfolk Island',
#   744430,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Kristina Rose',
#   'James and Sons',
#   'Actuary',
#   'Ricardomouth',
#   'Nicaragua',
#   46190,
#   'Intern',
#   1.4,
#   1.5],
#  ['Allison Mclaughlin',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Honduras',
#   740640,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Dylan Davenport',
#   'Nichols-James',
#   'Equities trader',
#   'Whitakerbury',
#   'Cambodia',
#   136500,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Charles Maynard',
#   'Matthews Inc',
#   'Administrator',
#   'Whiteside',
#   'Martinique',
#   287280,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Morgan Davis',
#   'Thomas-Spencer',
#   'Actuary',
#   'Whiteside',
#   'San Marino',
#   823660,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Sandra Mitchell',
#   'White, Mcclain and Cobb',
#   'Equities trader',
#   'West Jamesview',
#   'Equatorial Guinea',
#   940480,
#   'Intern',
#   4.3,
#   5.6],
#  ['Devin Crawford',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Somalia',
#   598860,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Christina Carlson',
#   'Bullock-Carrillo',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Slovakia (Slovak Republic)',
#   679520,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Randy Brown',
#   'Nelson-Li',
#   'Equities trader',
#   'Aliciafort',
#   'Uzbekistan',
#   121970,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Maria Mayo',
#   'Johnston, Fleming and Tanner',
#   'Energy manager',
#   'Whiteside',
#   'Iceland',
#   225490,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Marcus Hall',
#   'Wallace, Smith and Shepard',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Greenland',
#   214970,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Carl Trevino',
#   'Nichols-James',
#   'Actuary',
#   'Whitakerbury',
#   'Paraguay',
#   257350,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Nicole Wilkins',
#   'Andrade LLC',
#   'Ergonomist',
#   'Whitakerbury',
#   'Namibia',
#   975090,
#   'Full Time',
#   1.7,
#   1.5],
#  ['James Cox',
#   'Scott Inc',
#   'Production engineer',
#   'North Melissafurt',
#   'Afghanistan',
#   63280,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Michael Cooper',
#   'Matthews Inc',
#   'Energy manager',
#   'Kristaburgh',
#   'Ecuador',
#   553230,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Michelle Hoffman',
#   'Taylor-Ramos',
#   'Regulatory affairs officer',
#   'West Jamesview',
#   'Chad',
#   480420,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Allen Grant',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Saint Vincent and the Grenadines',
#   475820,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Amanda Arnold',
#   'Nelson-Li',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Congo',
#   43810,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Jennifer Olson',
#   'Wallace, Smith and Shepard',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Thailand',
#   707060,
#   'Intern',
#   4.0,
#   5.0],
#  ['Thomas Cooper',
#   'James and Sons',
#   'Regulatory affairs officer',
#   'West Jamesview',
#   'Germany',
#   877980,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Derek Galloway',
#   'Bullock-Carrillo',
#   'Garment/textile technologist',
#   'Whitakerbury',
#   'French Guiana',
#   697400,
#   'Intern',
#   1.7,
#   1.5],
#  ['Ryan Crawford',
#   'White, Mcclain and Cobb',
#   'Sales promotion account executive',
#   'Aliciafort',
#   'Togo',
#   39400,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Jeremy Taylor',
#   'Nelson-Li',
#   'Regulatory affairs officer',
#   'New Cindychester',
#   'Botswana',
#   637930,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Phillip Stanton',
#   'Nelson-Li',
#   'Equities trader',
#   'New Cindychester',
#   'Luxembourg',
#   769840,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Sarah Bryan',
#   'Marshall-Holloway',
#   'Trading standards officer',
#   'Whiteside',
#   'Dominica',
#   117300,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Emily Ayala',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Czech Republic',
#   963680,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Emma Garcia',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'New Cindychester',
#   'Ethiopia',
#   958130,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Lauren Thompson',
#   'Matthews Inc',
#   'Patent examiner',
#   'New Cindychester',
#   'American Samoa',
#   584900,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Tiffany Gross',
#   'Scott Inc',
#   'Optometrist',
#   'Aliciafort',
#   'Korea',
#   836110,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Tyler Nash',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'San Marino',
#   471940,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Shelby Brown',
#   'Marshall-Holloway',
#   'Equities trader',
#   'New Cindychester',
#   'Vanuatu',
#   957080,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Michael Snyder',
#   'James and Sons',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'Syrian Arab Republic',
#   465280,
#   'Intern',
#   4.5,
#   6.0],
#  ['Michael Gardner',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Wardfort',
#   'Sweden',
#   78620,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Pamela Romero',
#   'Andrade LLC',
#   'Trading standards officer',
#   'Wardfort',
#   'Northern Mariana Islands',
#   828810,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Sonya Davis',
#   'Baker, Allen and Edwards',
#   'Armed forces logistics/support/administrative officer',
#   'Kristaburgh',
#   'Marshall Islands',
#   512499,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Emma Kim',
#   'Marshall-Holloway',
#   'Optometrist',
#   'New Cindychester',
#   "Cote d'Ivoire",
#   85940,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Victoria Anthony',
#   'Campos, Reynolds and Mccormick',
#   'Administrator',
#   'Wardfort',
#   'Iceland',
#   856940,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Pamela Howard',
#   'Campos, Reynolds and Mccormick',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Azerbaijan',
#   251740,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Ann White',
#   'Scott Inc',
#   'Ergonomist',
#   'North Melissafurt',
#   'Estonia',
#   724860,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Christine Campos',
#   'White, Mcclain and Cobb',
#   'Radiographer, therapeutic',
#   'Whiteside',
#   'Albania',
#   524610,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Brandi Zimmerman',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Wallis and Futuna',
#   38580,
#   'Intern',
#   0.9,
#   1.5],
#  ['Michael Anderson',
#   'White, Mcclain and Cobb',
#   'Energy manager',
#   'New Russellton',
#   'Turks and Caicos Islands',
#   595060,
#   'Intern',
#   2.0,
#   1.5],
#  ['Kevin Mclaughlin',
#   'Andrade LLC',
#   'Ergonomist',
#   'Kristaburgh',
#   'Korea',
#   332390,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Tanya Martinez',
#   'Nelson-Li',
#   'Retail merchandiser',
#   'Whiteside',
#   'Czech Republic',
#   641330,
#   'Full Time',
#   1.4,
#   1.5],
#  ['David Marquez',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'New Cindychester',
#   'Falkland Islands (Malvinas)',
#   687990,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Ebony Trujillo',
#   'James and Sons',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Ireland',
#   821840,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Shawn Shannon',
#   'Nelson-Li',
#   'Radiographer, therapeutic',
#   'Whitakerbury',
#   'Chad',
#   799690,
#   'Intern',
#   1.8,
#   1.5],
#  ['David Moore',
#   'Thomas-Spencer',
#   'Retail merchandiser',
#   'West Jamesview',
#   'Macao',
#   886260,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Heather Thomas',
#   'Campos, Reynolds and Mccormick',
#   'Retail merchandiser',
#   'Whiteside',
#   'Andorra',
#   294910,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Amy Tran',
#   'Thomas-Spencer',
#   'Actuary',
#   'Whiteside',
#   'Kiribati',
#   248130,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Keith Reid',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Whitakerbury',
#   'Romania',
#   343350,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Emily Smith',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'New Russellton',
#   'Netherlands Antilles',
#   827800,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Pamela Dawson',
#   'Nelson-Li',
#   'Patent examiner',
#   'Kristaburgh',
#   'Hong Kong',
#   117470,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Tony Brown',
#   'James and Sons',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Holy See (Vatican City State)',
#   563840,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Jeffery Braun',
#   'Bullock-Carrillo',
#   'Patent examiner',
#   'West Jamesview',
#   'Hong Kong',
#   180230,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Alexander Anderson',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Wallis and Futuna',
#   820170,
#   'Intern',
#   1.0,
#   1.5],
#  ['Nicole Johnson',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   568800,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Jeanne Smith',
#   'Marshall-Holloway',
#   'Energy manager',
#   'Kristaburgh',
#   'Bangladesh',
#   803770,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Roberto Kerr',
#   'Campos, Reynolds and Mccormick',
#   'Ergonomist',
#   'West Jamesview',
#   'Senegal',
#   857900,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Amy Parker',
#   'Johnston, Fleming and Tanner',
#   'Production engineer',
#   'Whiteside',
#   'Guyana',
#   777190,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Michael Johnston',
#   'Johnston, Fleming and Tanner',
#   'Trading standards officer',
#   'North Melissafurt',
#   'Reunion',
#   257540,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Mark Johnson',
#   'Johnston, Fleming and Tanner',
#   'Sales promotion account executive',
#   'New Cindychester',
#   'Mauritania',
#   235590,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Crystal Adams',
#   'Johnston, Fleming and Tanner',
#   'Investment banker, corporate',
#   'Wardfort',
#   'Senegal',
#   47350,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Anthony Short',
#   'Thomas-Spencer',
#   'Administrator',
#   'New Cindychester',
#   'Guinea',
#   454450,
#   'Full Time',
#   2.5,
#   2.0],
#  ['David Arias',
#   'Andrade LLC',
#   'Optometrist',
#   'Aliciafort',
#   'Sudan',
#   628270,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Kristen Hill',
#   'Nelson-Li',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Andorra',
#   725010,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Gregory Ford',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Aliciafort',
#   'Mexico',
#   570460,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Rachel Harrison',
#   'Johnston, Fleming and Tanner',
#   'Patent examiner',
#   'Wardfort',
#   'United Arab Emirates',
#   882730,
#   'Intern',
#   1.1,
#   1.5],
#  ['Noah Williams',
#   'Wallace, Smith and Shepard',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Azerbaijan',
#   864450,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Donna Hill',
#   'Marshall-Holloway',
#   'Make',
#   'North Melissafurt',
#   'Greece',
#   640870,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Emily Navarro',
#   'White, Mcclain and Cobb',
#   'Garment/textile technologist',
#   'West Jamesview',
#   'Timor-Leste',
#   930370,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Alexander Scott',
#   'Matthews Inc',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'American Samoa',
#   184700,
#   'Full Time',
#   0.5,
#   1.5],
#  ['William Dunn',
#   'Johnston, Fleming and Tanner',
#   'Regulatory affairs officer',
#   'Aliciafort',
#   'Georgia',
#   646430,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Robert Marshall',
#   'Scott Inc',
#   'Ergonomist',
#   'Kristaburgh',
#   'Saint Lucia',
#   925120,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Brian Thomas',
#   'Andrade LLC',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Sao Tome and Principe',
#   28890,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Christopher Wilson',
#   'Thomas-Spencer',
#   'Administrator',
#   'Whiteside',
#   'Japan',
#   838480,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Brian Moore',
#   'Johnston, Fleming and Tanner',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Philippines',
#   270580,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Jackie Arnold',
#   'Baker, Allen and Edwards',
#   'Patent examiner',
#   'North Melissafurt',
#   'Chad',
#   85920,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Benjamin Holt',
#   'Nelson-Li',
#   'Actuary',
#   'New Russellton',
#   'Saint Martin',
#   508399,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michael Spencer',
#   'Scott Inc',
#   'Optometrist',
#   'Ricardomouth',
#   'Argentina',
#   915190,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Justin Richards',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Guyana',
#   126690,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Danny Marsh',
#   'Andrade LLC',
#   'Administrator',
#   'New Russellton',
#   'Rwanda',
#   7280,
#   'Intern',
#   4.0,
#   5.0],
#  ['Tonya Rivera',
#   'Baker, Allen and Edwards',
#   'Retail merchandiser',
#   'North Melissafurt',
#   'Ethiopia',
#   106810,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Dalton Douglas',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Jordan',
#   126179,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Carrie Watts',
#   'Taylor-Ramos',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Suriname',
#   199530,
#   'Intern',
#   0.7,
#   1.5],
#  ['Matthew Crane',
#   'James and Sons',
#   'Actuary',
#   'North Melissafurt',
#   'Saint Kitts and Nevis',
#   595440,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Nathan Wright',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Slovakia (Slovak Republic)',
#   733110,
#   'Intern',
#   4.6,
#   6.199999999999999],
#  ['Kevin Williams',
#   'Taylor-Ramos',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Pitcairn Islands',
#   942600,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Wendy Irwin',
#   'Thomas-Spencer',
#   'Radiographer, therapeutic',
#   'New Cindychester',
#   'Poland',
#   716700,
#   'Full Time',
#   3.9,
#   4.8],
#  ['Teresa Reyes',
#   'Matthews Inc',
#   'Armed forces logistics/support/administrative officer',
#   'Wardfort',
#   'Dominica',
#   471310,
#   'Intern',
#   3.8,
#   4.6],
#  ['Ashley Lewis',
#   'Taylor-Ramos',
#   'Make',
#   'Ricardomouth',
#   'Tanzania',
#   541660,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Stephanie Bernard',
#   'Thomas-Spencer',
#   'Administrator',
#   'Aliciafort',
#   'Sri Lanka',
#   992230,
#   'Intern',
#   4.5,
#   6.0],
#  ['Jared Miranda',
#   'James and Sons',
#   'Actuary',
#   'New Cindychester',
#   'Argentina',
#   890310,
#   'Full Time',
#   0.4,
#   1.5],
#  ['David Collins',
#   'Andrade LLC',
#   'Ergonomist',
#   'Kristaburgh',
#   'Guyana',
#   226310,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Stuart Olson',
#   'James and Sons',
#   'Trading standards officer',
#   'Wardfort',
#   'Pitcairn Islands',
#   928390,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Lisa Wang',
#   'Scott Inc',
#   'Trading standards officer',
#   'Wardfort',
#   'Equatorial Guinea',
#   611000,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Lee Becker',
#   'Scott Inc',
#   'Equities trader',
#   'Aliciafort',
#   'Peru',
#   111460,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Travis Davis',
#   'Johnston, Fleming and Tanner',
#   'Investment banker, corporate',
#   'Ricardomouth',
#   'Solomon Islands',
#   790700,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Cody Carlson',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'Ricardomouth',
#   'Kenya',
#   919210,
#   'Intern',
#   1.8,
#   1.5],
#  ['Michael Larsen',
#   'Matthews Inc',
#   'Patent examiner',
#   'New Russellton',
#   'Vanuatu',
#   639300,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Steven Rodriguez',
#   'Baker, Allen and Edwards',
#   'Investment banker, corporate',
#   'New Russellton',
#   'South Georgia and the South Sandwich Islands',
#   841630,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Joshua Garrett',
#   'Scott Inc',
#   'Ergonomist',
#   'Aliciafort',
#   'Bosnia and Herzegovina',
#   958860,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Jessica Curtis',
#   'Marshall-Holloway',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   769760,
#   'Intern',
#   2.3,
#   1.5999999999999996],
#  ['Laura Walker',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Liechtenstein',
#   822040,
#   'Intern',
#   4.8,
#   6.6],
#  ['Megan Guerrero',
#   'Marshall-Holloway',
#   'Garment/textile technologist',
#   'Whiteside',
#   'Saint Vincent and the Grenadines',
#   706430,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Daniel Wood',
#   'Campos, Reynolds and Mccormick',
#   'Actuary',
#   'Ricardomouth',
#   'Romania',
#   735880,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Melissa Olson',
#   'Marshall-Holloway',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Mexico',
#   705050,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Emily Johnson',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'West Jamesview',
#   'Isle of Man',
#   251479,
#   'Intern',
#   0.2,
#   1.5],
#  ['Brett Gray',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'West Jamesview',
#   'Ghana',
#   536340,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Jeffrey Cardenas',
#   'Johnston, Fleming and Tanner',
#   'Patent examiner',
#   'Whitakerbury',
#   'Central African Republic',
#   237470,
#   'Full Time',
#   0.4,
#   1.5],
#  ['Shane Martinez',
#   'Andrade LLC',
#   'Make',
#   'New Cindychester',
#   'Martinique',
#   118680,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Margaret Vaughn',
#   'Bullock-Carrillo',
#   'Make',
#   'New Russellton',
#   "Lao People's Democratic Republic",
#   517970,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Johnathan Russell',
#   'Scott Inc',
#   'Naval architect',
#   'Whitakerbury',
#   'Algeria',
#   118760,
#   'Full Time',
#   0.9,
#   1.5],
#  ['Alexander Gonzales',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Bahrain',
#   449700,
#   'Intern',
#   1.4,
#   1.5],
#  ['Veronica Howard',
#   'Thomas-Spencer',
#   'Actuary',
#   'North Melissafurt',
#   'Iceland',
#   662260,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Brian Williams',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'Kristaburgh',
#   'Dominican Republic',
#   950960,
#   'Full Time',
#   3.0,
#   3.0],
#  ['John Thomas',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'North Melissafurt',
#   'French Polynesia',
#   458070,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Jamie Ramirez',
#   'Matthews Inc',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Samoa',
#   760910,
#   'Intern',
#   2.8,
#   2.5999999999999996],
#  ['Gabriel Spencer',
#   'Johnston, Fleming and Tanner',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Saint Vincent and the Grenadines',
#   832880,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Kristen Newman',
#   'Matthews Inc',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Poland',
#   125190,
#   'Intern',
#   0.9,
#   1.5],
#  ['Lisa Hunter',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'Aliciafort',
#   'Svalbard & Jan Mayen Islands',
#   815100,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Andrew Martin',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Hungary',
#   784000,
#   'Intern',
#   2.6,
#   2.2],
#  ['William Aguilar',
#   'Wallace, Smith and Shepard',
#   'Optometrist',
#   'New Russellton',
#   'French Polynesia',
#   467900,
#   'Intern',
#   1.2,
#   1.5],
#  ['David Harper',
#   'Thomas-Spencer',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Sri Lanka',
#   211370,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Janice Jennings',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'Kristaburgh',
#   'Dominican Republic',
#   266830,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Jennifer Howe',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'Bangladesh',
#   741960,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Donna Robinson',
#   'Andrade LLC',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   "Lao People's Democratic Republic",
#   194650,
#   'Full Time',
#   1.6,
#   1.5],
#  ['William Sanchez',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'Kristaburgh',
#   'Saint Martin',
#   199960,
#   'Intern',
#   1.8,
#   1.5],
#  ['Tracy Holmes',
#   'Bullock-Carrillo',
#   'Energy manager',
#   'Wardfort',
#   'American Samoa',
#   250220,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Scott Martinez',
#   'Marshall-Holloway',
#   'Make',
#   'New Russellton',
#   'Hong Kong',
#   702170,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Margaret Huerta',
#   'Wallace, Smith and Shepard',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Eritrea',
#   761000,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Joel Hatfield',
#   'White, Mcclain and Cobb',
#   'Optometrist',
#   'Kristaburgh',
#   'Saint Lucia',
#   320030,
#   'Intern',
#   0.2,
#   1.5],
#  ['Grace Hester',
#   'Nelson-Li',
#   'Naval architect',
#   'Whitakerbury',
#   'Netherlands',
#   452360,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Jackson Allen',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Congo',
#   248290,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Emily Allen',
#   'White, Mcclain and Cobb',
#   'Patent examiner',
#   'Aliciafort',
#   'Azerbaijan',
#   892050,
#   'Intern',
#   1.9,
#   1.5],
#  ['Joseph Church',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Malaysia',
#   307620,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Walter Jones',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Ricardomouth',
#   'Panama',
#   746790,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Amanda Edwards',
#   'Andrade LLC',
#   'Regulatory affairs officer',
#   'Whiteside',
#   'United States Virgin Islands',
#   767500,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Trevor Garcia',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'Aliciafort',
#   'Cuba',
#   772310,
#   'Intern',
#   3.1,
#   3.2],
#  ['Steven Hampton',
#   'Andrade LLC',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Bulgaria',
#   561240,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Diana Wright',
#   'Campos, Reynolds and Mccormick',
#   'Garment/textile technologist',
#   'New Cindychester',
#   'Armenia',
#   755470,
#   'Intern',
#   0.6,
#   1.5],
#  ['Samuel Stevenson',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'Whiteside',
#   'French Polynesia',
#   997690,
#   'Full Time',
#   1.5,
#   1.5],
#  ['Patrick Curtis',
#   'White, Mcclain and Cobb',
#   'Actuary',
#   'New Russellton',
#   'Estonia',
#   273580,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Joseph Ballard',
#   'Marshall-Holloway',
#   'Actuary',
#   'Whiteside',
#   'South Georgia and the South Sandwich Islands',
#   697730,
#   'Intern',
#   3.8,
#   4.6],
#  ['Susan Nixon',
#   'Campos, Reynolds and Mccormick',
#   'Armed forces logistics/support/administrative officer',
#   'Ricardomouth',
#   'Lebanon',
#   666900,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Brenda Allen',
#   'Matthews Inc',
#   'Trading standards officer',
#   'West Jamesview',
#   'Chile',
#   816360,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Michael Mercer',
#   'Marshall-Holloway',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Antigua and Barbuda',
#   345500,
#   'Intern',
#   3.2,
#   3.4000000000000004],
#  ['Rebecca Bennett',
#   'Johnston, Fleming and Tanner',
#   'Armed forces logistics/support/administrative officer',
#   'West Jamesview',
#   'Jordan',
#   851800,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Dawn Hicks',
#   'Taylor-Ramos',
#   'Naval architect',
#   'Whiteside',
#   'Botswana',
#   711010,
#   'Full Time',
#   0.2,
#   1.5],
#  ['Lisa Lewis',
#   'Scott Inc',
#   'Energy manager',
#   'Ricardomouth',
#   'Switzerland',
#   717820,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Barbara Page',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'West Jamesview',
#   'Martinique',
#   148260,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Gina Oneal',
#   'Scott Inc',
#   'Ergonomist',
#   'Whiteside',
#   'Guadeloupe',
#   987730,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Samantha Butler',
#   'Andrade LLC',
#   'Ergonomist',
#   'Aliciafort',
#   'Isle of Man',
#   639990,
#   'Intern',
#   1.7,
#   1.5],
#  ['Kristin Adams',
#   'Baker, Allen and Edwards',
#   'Energy manager',
#   'New Russellton',
#   'Cayman Islands',
#   380780,
#   'Full Time',
#   2.1,
#   1.5],
#  ['William Charles',
#   'Matthews Inc',
#   'Optometrist',
#   'Kristaburgh',
#   'Peru',
#   585590,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Stephen Lopez',
#   'Scott Inc',
#   'Equities trader',
#   'Wardfort',
#   'Grenada',
#   492280,
#   'Intern',
#   4.1,
#   5.199999999999999],
#  ['Melissa Garcia',
#   'Nichols-James',
#   'Naval architect',
#   'Wardfort',
#   'Ethiopia',
#   490720,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Dan Scott',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Niger',
#   219690,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Thomas Nichols',
#   'Scott Inc',
#   'Production engineer',
#   'Whiteside',
#   'Libyan Arab Jamahiriya',
#   180820,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Danny Bryan',
#   'Nelson-Li',
#   'Sales promotion account executive',
#   'Whitakerbury',
#   'Monaco',
#   402590,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Ricky Hahn',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'West Jamesview',
#   'Iran',
#   802400,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Lisa Vance',
#   'Wallace, Smith and Shepard',
#   'Armed forces logistics/support/administrative officer',
#   'Whitakerbury',
#   'Tuvalu',
#   607350,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Kyle Weiss',
#   'Nelson-Li',
#   'Optometrist',
#   'New Cindychester',
#   'New Zealand',
#   435870,
#   'Full Time',
#   3.1,
#   3.2],
#  ['Judy Gonzalez',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'New Russellton',
#   'Suriname',
#   555730,
#   'Intern',
#   0.6,
#   1.5],
#  ['Michael Baker',
#   'Bullock-Carrillo',
#   'Production engineer',
#   'New Russellton',
#   'Namibia',
#   499220,
#   'Full Time',
#   2.0,
#   1.5],
#  ['Michael Castro',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Ricardomouth',
#   'Saint Lucia',
#   687320,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Katherine Perez',
#   'Andrade LLC',
#   'Production engineer',
#   'New Cindychester',
#   'Turks and Caicos Islands',
#   831950,
#   'Full Time',
#   2.3,
#   1.5999999999999996],
#  ['Kathy Vazquez',
#   'Baker, Allen and Edwards',
#   'Optometrist',
#   'Aliciafort',
#   'Austria',
#   537050,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Cynthia Wood',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'Whiteside',
#   'Saint Kitts and Nevis',
#   638000,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Justin Rivas',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'Ricardomouth',
#   'Hungary',
#   990920,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Hunter Mccormick',
#   'Bullock-Carrillo',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Tunisia',
#   331840,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Patrick Villarreal',
#   'Wallace, Smith and Shepard',
#   'Energy manager',
#   'Kristaburgh',
#   'Hungary',
#   160470,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Ryan Brown',
#   'Campos, Reynolds and Mccormick',
#   'Optometrist',
#   'Ricardomouth',
#   'Uganda',
#   406850,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Thomas Buck',
#   'Andrade LLC',
#   'Make',
#   'New Cindychester',
#   'Czech Republic',
#   270930,
#   'Full Time',
#   1.9,
#   1.5],
#  ['Sherri Wallace',
#   'Matthews Inc',
#   'Optometrist',
#   'Wardfort',
#   'Papua New Guinea',
#   534140,
#   'Full Time',
# ...
#   'Trading standards officer',
#   'New Russellton',
#   'Papua New Guinea',
#   356630,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Monique Turner',
#   'Wallace, Smith and Shepard',
#   'Actuary',
#   'Wardfort',
#   'Bulgaria',
#   265470,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Kyle Riddle',
#   'Bullock-Carrillo',
#   'Trading standards officer',
#   'New Cindychester',
#   'Georgia',
#   781160,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Stacey Cervantes',
#   'James and Sons',
#   'Equities trader',
#   'North Melissafurt',
#   'Guam',
#   700630,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Theresa Mason',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Djibouti',
#   73390,
#   'Full Time',
#   2.7,
#   2.4000000000000004],
#  ['Stephanie Flores',
#   'Thomas-Spencer',
#   'Garment/textile technologist',
#   'Ricardomouth',
#   'Croatia',
#   859710,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Tammy Murray',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Kristaburgh',
#   'Nigeria',
#   356390,
#   'Intern',
#   0.9,
#   1.5],
#  ['Shane Miller',
#   'Bullock-Carrillo',
#   'Regulatory affairs officer',
#   'North Melissafurt',
#   'Lithuania',
#   827440,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Elizabeth Rivera',
#   'Bullock-Carrillo',
#   'Investment banker, corporate',
#   'Aliciafort',
#   'United States of America',
#   35490,
#   'Full Time',
#   0.8,
#   1.5],
#  ['Robert Ferguson',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Whiteside',
#   'Cocos (Keeling) Islands',
#   480080,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Christopher Ruiz',
#   'Marshall-Holloway',
#   'Actuary',
#   'Whitakerbury',
#   'Netherlands Antilles',
#   295160,
#   'Full Time',
#   1.4,
#   1.5],
#  ['Judy Jimenez',
#   'Bullock-Carrillo',
#   'Naval architect',
#   'Ricardomouth',
#   'Nepal',
#   453980,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['David Thomas',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Guernsey',
#   271280,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Larry Bruce',
#   'James and Sons',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Bosnia and Herzegovina',
#   62790,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Richard Kelly',
#   'Campos, Reynolds and Mccormick',
#   'Make',
#   'North Melissafurt',
#   'United States Minor Outlying Islands',
#   970750,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Christopher Lee',
#   'Marshall-Holloway',
#   'Make',
#   'Ricardomouth',
#   'Andorra',
#   304140,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Wendy Day',
#   'Taylor-Ramos',
#   'Trading standards officer',
#   'West Jamesview',
#   'Saint Kitts and Nevis',
#   302500,
#   'Full Time',
#   0.0,
#   1.5],
#  ['Riley Clark',
#   'Bullock-Carrillo',
#   'Actuary',
#   'Wardfort',
#   'Hong Kong',
#   89870,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Brandon Walsh',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Netherlands',
#   964970,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Philip Mendoza',
#   'James and Sons',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'Serbia',
#   230630,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Anthony Richard',
#   'Andrade LLC',
#   'Actuary',
#   'North Melissafurt',
#   'Armenia',
#   785080,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Kyle Coleman',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'North Melissafurt',
#   'Sri Lanka',
#   199510,
#   'Full Time',
#   4.4,
#   5.800000000000001],
#  ['Justin Mccarty',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'New Cindychester',
#   'Sierra Leone',
#   356890,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Tracy Brown',
#   'Nelson-Li',
#   'Energy manager',
#   'Whiteside',
#   "Cote d'Ivoire",
#   246860,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Monica Hill',
#   'Scott Inc',
#   'Retail merchandiser',
#   'North Melissafurt',
#   'Eritrea',
#   478850,
#   'Full Time',
#   2.2,
#   1.5],
#  ['Jackie Oconnor',
#   'Baker, Allen and Edwards',
#   'Diplomatic Services operational officer',
#   'West Jamesview',
#   'Poland',
#   851360,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Lisa Warren',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Uruguay',
#   337050,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Tracy Allen',
#   'Wallace, Smith and Shepard',
#   'Trading standards officer',
#   'New Russellton',
#   'Norfolk Island',
#   911830,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Juan Henderson',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'North Melissafurt',
#   'Iran',
#   233880,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Kevin Martin',
#   'Campos, Reynolds and Mccormick',
#   'Trading standards officer',
#   'Whitakerbury',
#   'Georgia',
#   742310,
#   'Full Time',
#   4.5,
#   6.0],
#  ['Steven Bailey',
#   'Andrade LLC',
#   'Garment/textile technologist',
#   'Wardfort',
#   'Saint Kitts and Nevis',
#   93560,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Juan Dawson',
#   'Marshall-Holloway',
#   'Diplomatic Services operational officer',
#   'Aliciafort',
#   'Switzerland',
#   713630,
#   'Full Time',
#   1.2,
#   1.5],
#  ['Kyle Hamilton',
#   'Campos, Reynolds and Mccormick',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Palestinian Territory',
#   20500,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Stacey Mata',
#   'Nichols-James',
#   'Patent examiner',
#   'Whiteside',
#   'Holy See (Vatican City State)',
#   39290,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Antonio Greene',
#   'Baker, Allen and Edwards',
#   'Administrator',
#   'Aliciafort',
#   'Syrian Arab Republic',
#   373420,
#   'Full Time',
#   0.3,
#   1.5],
#  ['Alicia Vincent',
#   'Johnston, Fleming and Tanner',
#   'Sales promotion account executive',
#   'Ricardomouth',
#   'Central African Republic',
#   643450,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Heather Lewis',
#   'White, Mcclain and Cobb',
#   'Trading standards officer',
#   'Ricardomouth',
#   'Northern Mariana Islands',
#   864770,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Gabrielle Robinson',
#   'White, Mcclain and Cobb',
#   'Ergonomist',
#   'New Russellton',
#   'El Salvador',
#   198940,
#   'Full Time',
#   4.3,
#   5.6],
#  ['John Petty',
#   'Thomas-Spencer',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Libyan Arab Jamahiriya',
#   107890,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Tommy Williams',
#   'Nelson-Li',
#   'Optometrist',
#   'Whiteside',
#   'Faroe Islands',
#   1440,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Carrie Moore',
#   'Nelson-Li',
#   'Equities trader',
#   'Whiteside',
#   'Tokelau',
#   21800,
#   'Intern',
#   2.2,
#   1.5],
#  ['Claudia Pacheco',
#   'Wallace, Smith and Shepard',
#   'Naval architect',
#   'Whiteside',
#   'Grenada',
#   269470,
#   'Full Time',
#   3.0,
#   3.0],
#  ['Alex Kim',
#   'Scott Inc',
#   'Trading standards officer',
#   'Kristaburgh',
#   'Denmark',
#   705660,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['James Campbell',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Wardfort',
#   'Somalia',
#   627200,
#   'Full Time',
#   4.0,
#   5.0],
#  ['Justin Underwood',
#   'Matthews Inc',
#   'Investment banker, corporate',
#   'Kristaburgh',
#   'Belgium',
#   942480,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Nicole Jordan',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'United Kingdom',
#   590690,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Rachel Carpenter',
#   'Wallace, Smith and Shepard',
#   'Administrator',
#   'Whiteside',
#   'Saint Kitts and Nevis',
#   640110,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Melissa Booth',
#   'Nichols-James',
#   'Investment banker, corporate',
#   'New Cindychester',
#   'Cuba',
#   285450,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Holly Small',
#   'Matthews Inc',
#   'Investment banker, corporate',
#   'New Russellton',
#   'Gambia',
#   239980,
#   'Full Time',
#   3.2,
#   3.4000000000000004],
#  ['Anthony Doyle',
#   'White, Mcclain and Cobb',
#   'Armed forces logistics/support/administrative officer',
#   'North Melissafurt',
#   'Senegal',
#   237470,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Matthew Day',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'New Russellton',
#   'New Zealand',
#   398380,
#   'Full Time',
#   2.5,
#   2.0],
#  ['Gregory Kennedy',
#   'Campos, Reynolds and Mccormick',
#   'Production engineer',
#   'Wardfort',
#   'Seychelles',
#   794100,
#   'Intern',
#   1.5,
#   1.5],
#  ['Travis Clark',
#   'White, Mcclain and Cobb',
#   'Make',
#   'New Cindychester',
#   'Kenya',
#   747640,
#   'Full Time',
#   1.8,
#   1.5],
#  ['Richard Castro',
#   'Johnston, Fleming and Tanner',
#   'Optometrist',
#   'Kristaburgh',
#   'Thailand',
#   640860,
#   'Full Time',
#   3.5,
#   4.0],
#  ['Raymond Clark',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'Wardfort',
#   'Korea',
#   616190,
#   'Full Time',
#   4.6,
#   6.199999999999999],
#  ['Charles Griffin',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Trinidad and Tobago',
#   897560,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Robert Rogers',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'North Melissafurt',
#   'Pitcairn Islands',
#   840600,
#   'Full Time',
#   1.1,
#   1.5],
#  ['Stacey Heath',
#   'Andrade LLC',
#   'Actuary',
#   'Whitakerbury',
#   'Martinique',
#   281000,
#   'Full Time',
#   0.7,
#   1.5],
#  ['Jennifer Foster',
#   'Johnston, Fleming and Tanner',
#   'Equities trader',
#   'Whitakerbury',
#   'Somalia',
#   24390,
#   'Full Time',
#   1.6,
#   1.5],
#  ['Mary Becker',
#   'Andrade LLC',
#   'Ergonomist',
#   'Wardfort',
#   'Switzerland',
#   755730,
#   'Full Time',
#   3.6,
#   4.2],
#  ['Marcus Fisher',
#   'Taylor-Ramos',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Malta',
#   211200,
#   'Intern',
#   4.7,
#   6.4],
#  ['Christy Murphy',
#   'Wallace, Smith and Shepard',
#   'Armed forces logistics/support/administrative officer',
#   'Kristaburgh',
#   'Marshall Islands',
#   739860,
#   'Intern',
#   4.1,
#   5.199999999999999],
#  ['Miguel Morales',
#   'Marshall-Holloway',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Dominican Republic',
#   482130,
#   'Intern',
#   0.2,
#   1.5],
#  ['Christopher Lee',
#   'Campos, Reynolds and Mccormick',
#   'Naval architect',
#   'Aliciafort',
#   'Austria',
#   186670,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Amanda Caldwell',
#   'Bullock-Carrillo',
#   'Optometrist',
#   'North Melissafurt',
#   'Liechtenstein',
#   286490,
#   'Intern',
#   4.3,
#   5.6],
#  ['Christopher Harris',
#   'Marshall-Holloway',
#   'Regulatory affairs officer',
#   'Kristaburgh',
#   'Spain',
#   821760,
#   'Full Time',
#   3.4,
#   3.8],
#  ['Timothy Griffin',
#   'Baker, Allen and Edwards',
#   'Equities trader',
#   'Whitakerbury',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   322220,
#   'Full Time',
#   4.8,
#   6.6],
#  ['Yolanda Logan',
#   'Thomas-Spencer',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'Bahrain',
#   720650,
#   'Intern',
#   3.3,
#   3.5999999999999996],
#  ['Felicia Thomas',
#   'White, Mcclain and Cobb',
#   'Diplomatic Services operational officer',
#   'Wardfort',
#   'Jersey',
#   408960,
#   'Intern',
#   2.1,
#   1.5],
#  ['Christine Peters',
#   'Taylor-Ramos',
#   'Naval architect',
#   'Aliciafort',
#   'Falkland Islands (Malvinas)',
#   278550,
#   'Intern',
#   3.9,
#   4.8],
#  ['Justin White',
#   'Baker, Allen and Edwards',
#   'Ergonomist',
#   'Ricardomouth',
#   'Thailand',
#   995750,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Brenda Sloan',
#   'Andrade LLC',
#   'Patent examiner',
#   'Kristaburgh',
#   'Netherlands Antilles',
#   116720,
#   'Intern',
#   4.8,
#   6.6],
#  ['Philip Brooks',
#   'Campos, Reynolds and Mccormick',
#   'Administrator',
#   'Wardfort',
#   'Ethiopia',
#   444080,
#   'Intern',
#   4.8,
#   6.6],
#  ['Robert Moore',
#   'Nichols-James',
#   'Diplomatic Services operational officer',
#   'New Russellton',
#   'Iceland',
#   729380,
#   'Full Time',
#   2.5,
#   2.0],
#  ['Carl Carney',
#   'Taylor-Ramos',
#   'Garment/textile technologist',
#   'North Melissafurt',
#   'Saint Barthelemy',
#   197810,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Bradley Mitchell',
#   'Wallace, Smith and Shepard',
#   'Patent examiner',
#   'Wardfort',
#   'Timor-Leste',
#   71190,
#   'Intern',
#   0.6,
#   1.5],
#  ['Mark Hill',
#   'Johnston, Fleming and Tanner',
#   'Make',
#   'Kristaburgh',
#   'Swaziland',
#   898610,
#   'Full Time',
#   3.7,
#   4.4],
#  ['Cody Kline',
#   'Andrade LLC',
#   'Naval architect',
#   'Kristaburgh',
#   'Jersey',
#   619270,
#   'Intern',
#   2.4,
#   1.7999999999999998],
#  ['Debra Phillips',
#   'Matthews Inc',
#   'Diplomatic Services operational officer',
#   'Whitakerbury',
#   'India',
#   733660,
#   'Full Time',
#   4.2,
#   5.4],
#  ['Sarah Compton',
#   'Johnston, Fleming and Tanner',
#   'Naval architect',
#   'North Melissafurt',
#   'Eritrea',
#   438290,
#   'Full Time',
#   2.6,
#   2.2],
#  ['Lisa Norris',
#   'Matthews Inc',
#   'Actuary',
#   'West Jamesview',
#   'Cambodia',
#   797710,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Christopher Hall',
#   'Nichols-James',
#   'Optometrist',
#   'Whitakerbury',
#   'Burundi',
#   138250,
#   'Full Time',
#   1.7,
#   1.5],
#  ['Vincent Burton',
#   'Nichols-James',
#   'Actuary',
#   'Ricardomouth',
#   'Macedonia',
#   436170,
#   'Full Time',
#   4.9,
#   6.800000000000001],
#  ['Amy Johnson',
#   'Scott Inc',
#   'Investment banker, corporate',
#   'Whitakerbury',
#   'Holy See (Vatican City State)',
#   138270,
#   'Intern',
#   0.9,
#   1.5],
#  ['Hunter Ward',
#   'Scott Inc',
#   'Retail merchandiser',
#   'Wardfort',
#   'Seychelles',
#   304850,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Scott Benitez',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'North Melissafurt',
#   'Christmas Island',
#   848960,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Jesus Harrington',
#   'Scott Inc',
#   'Diplomatic Services operational officer',
#   'Kristaburgh',
#   'Kiribati',
#   264880,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Charles Johnston',
#   'Nelson-Li',
#   'Naval architect',
#   'Whiteside',
#   "Cote d'Ivoire",
#   202780,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Katherine Horn',
#   'Johnston, Fleming and Tanner',
#   'Retail merchandiser',
#   'New Cindychester',
#   'Denmark',
#   559050,
#   'Full Time',
#   1.3,
#   1.5],
#  ['Tyler Clark',
#   'Andrade LLC',
#   'Make',
#   'Ricardomouth',
#   'Ukraine',
#   475050,
#   'Full Time',
#   0.6,
#   1.5],
#  ['Devon Fowler',
#   'Nelson-Li',
#   'Regulatory affairs officer',
#   'New Cindychester',
#   'Libyan Arab Jamahiriya',
#   16209,
#   'Full Time',
#   4.3,
#   5.6],
#  ['Joseph Williams',
#   'Scott Inc',
#   'Naval architect',
#   'Whitakerbury',
#   'Slovenia',
#   944160,
#   'Full Time',
#   4.7,
#   6.4],
#  ['Sandra Duncan',
#   'Bullock-Carrillo',
#   'Administrator',
#   'Whiteside',
#   'Qatar',
#   683300,
#   'Full Time',
#   3.8,
#   4.6],
#  ['Anthony Harris',
#   'Nelson-Li',
#   'Administrator',
#   'Whiteside',
#   'Liechtenstein',
#   914540,
#   'Full Time',
#   1.0,
#   1.5],
#  ['Alex Kane',
#   'Thomas-Spencer',
#   'Production engineer',
#   'New Russellton',
#   'Germany',
#   317690,
#   'Full Time',
#   3.3,
#   3.5999999999999996],
#  ['Justin Cardenas',
#   'Johnston, Fleming and Tanner',
#   'Actuary',
#   'Whiteside',
#   'Niger',
#   374270,
#   'Full Time',
#   1.9,
#   1.5],
#  ['William Marshall',
#   'Andrade LLC',
#   'Diplomatic Services operational officer',
#   'Whiteside',
#   'Cocos (Keeling) Islands',
#   601090,
#   'Intern',
#   3.4,
#   3.8],
#  ['Valerie Robinson',
#   'James and Sons',
#   'Diplomatic Services operational officer',
#   'Ricardomouth',
#   'Colombia',
#   311590,
#   'Full Time',
#   2.1,
#   1.5],
#  ['Omar George',
#   'Campos, Reynolds and Mccormick',
#   'Radiographer, therapeutic',
#   'New Russellton',
#   'Bolivia',
#   656900,
#   'Full Time',
#   2.4,
#   1.7999999999999998],
#  ['Charles Merritt',
#   'Andrade LLC',
#   'Ergonomist',
#   'New Cindychester',
#   'Barbados',
#   108260,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Guy Rice',
#   'Matthews Inc',
#   'Equities trader',
#   'Kristaburgh',
#   'Montenegro',
#   247730,
#   'Full Time',
#   4.1,
#   5.199999999999999],
#  ['Corey White',
#   'Baker, Allen and Edwards',
#   'Radiographer, therapeutic',
#   'Aliciafort',
#   'Syrian Arab Republic',
#   572960,
#   'Full Time',
#   2.9,
#   2.8],
#  ['Ashley Harmon',
#   'Matthews Inc',
#   'Energy manager',
#   'New Russellton',
#   'Morocco',
#   778470,
#   'Intern',
#   1.5,
#   1.5],
#  ['James Hines',
#   'Baker, Allen and Edwards',
#   'Naval architect',
#   'Wardfort',
#   'Iran',
#   64810,
#   'Full Time',
#   1.0,
#   1.5],
#  ['William Lloyd',
#   'Baker, Allen and Edwards',
#   'Sales promotion account executive',
#   'New Russellton',
#   'Hong Kong',
#   643010,
#   'Full Time',
#   0.5,
#   1.5],
#  ['Jasmine Miller',
#   'White, Mcclain and Cobb',
#   'Make',
#   'Whitakerbury',
#   'Ethiopia',
#   885790,
#   'Intern',
#   4.8,
#   6.6],
#  ['Daniel Weiss',
#   'Campos, Reynolds and Mccormick',
#   'Patent examiner',
#   'Aliciafort',
#   'Lebanon',
#   821760,
#   'Full Time',
#   2.8,
#   2.5999999999999996],
#  ['Sara Wolfe',
#   'Andrade LLC',
#   'Radiographer, therapeutic',
#   'Kristaburgh',
#   'Tokelau',
#   750450,
#   'Full Time',
#   4.2,
#   5.4],
#  ...]

# %% [markdown]
# ### 119. Convert the 'Name' to upper case and store it back to the same column.

# %%
df["Name"] = df["Name"].apply(lambda x : x.upper())

df.head()
# Out:
#              Name                  Company_Name
# 0  SPENCER ADKINS                James and Sons  \
# 1    JULIE MORTON                 Nichols-James
# 2    MATTHEW HALL                     Scott Inc
# 3      BRAD SCOTT  Johnston, Fleming and Tanner
# 4   THERESA OWENS      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City
# 0                          Equities trader     New Russellton  \
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9  \
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8
#
#    Employee_Rating_New
# 0                  4.8
# 1                  5.6
# 2                  3.2
# 3                  3.2
# 4                  6.6

# %% [markdown]
# ### 120. Rearrange the columns in the below order. Overwrite to the current DataFrame object.

# %%
new_order = ["Name", "Employee_Job_Title", "Company_Name", 
             "Employee_City", "Employee_Country", "Employment_Status", 
             "Employee_Salary", "Employee_Rating", "Employee_Rating_New"]

df = df.loc[:,new_order]

df.head()
# Out:
#              Name                       Employee_Job_Title
# 0  SPENCER ADKINS                          Equities trader  \
# 1    JULIE MORTON  Diplomatic Services operational officer
# 2    MATTHEW HALL               Regulatory affairs officer
# 3      BRAD SCOTT                      Production engineer
# 4   THERESA OWENS                      Production engineer
#
#                    Company_Name      Employee_City       Employee_Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_Status  Employee_Salary  Employee_Rating  Employee_Rating_New
# 0         Full Time           321520              3.9                  4.8
# 1         Full Time           589090              4.3                  5.6
# 2         Full Time           630890              3.1                  3.2
# 3         Full Time           116400              3.1                  3.2
# 4         Full Time           523499              4.8                  6.6

# %% [markdown]
# ### 121. Add a New column of 'First_name' and compute it from the 'Name' column

# %%
df["First_name"] = df["Name"].apply(lambda x: x.split()[0])

df.head()
# Out:
#              Name                       Employee_Job_Title
# 0  SPENCER ADKINS                          Equities trader  \
# 1    JULIE MORTON  Diplomatic Services operational officer
# 2    MATTHEW HALL               Regulatory affairs officer
# 3      BRAD SCOTT                      Production engineer
# 4   THERESA OWENS                      Production engineer
#
#                    Company_Name      Employee_City       Employee_Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_Status  Employee_Salary  Employee_Rating  Employee_Rating_New
# 0         Full Time           321520              3.9                  4.8  \
# 1         Full Time           589090              4.3                  5.6
# 2         Full Time           630890              3.1                  3.2
# 3         Full Time           116400              3.1                  3.2
# 4         Full Time           523499              4.8                  6.6
#
#   First_name
# 0    SPENCER
# 1      JULIE
# 2    MATTHEW
# 3       BRAD
# 4    THERESA

# %% [markdown]
# ### 122. Add a New column of 'Last_name' and compute it from the 'Name' column

# %%
df["Last_name"] = df["Name"].apply(lambda x: x.split()[-1])

df.head()
# Out:
#              Name                       Employee_Job_Title
# 0  SPENCER ADKINS                          Equities trader  \
# 1    JULIE MORTON  Diplomatic Services operational officer
# 2    MATTHEW HALL               Regulatory affairs officer
# 3      BRAD SCOTT                      Production engineer
# 4   THERESA OWENS                      Production engineer
#
#                    Company_Name      Employee_City       Employee_Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_Status  Employee_Salary  Employee_Rating  Employee_Rating_New
# 0         Full Time           321520              3.9                  4.8  \
# 1         Full Time           589090              4.3                  5.6
# 2         Full Time           630890              3.1                  3.2
# 3         Full Time           116400              3.1                  3.2
# 4         Full Time           523499              4.8                  6.6
#
#   First_name Last_name
# 0    SPENCER    ADKINS
# 1      JULIE    MORTON
# 2    MATTHEW      HALL
# 3       BRAD     SCOTT
# 4    THERESA     OWENS

# %% [markdown]
# ### 123. Drop the 'Name' column inplace from the DataFrame.

# %%
df.drop(columns=["Name"],inplace=True)

# %% [markdown]
# ### 124. Rearrange the columns in the below order. Overwrite to the current DataFrame object.

# %%
new_order = ["First_name", "Last_name", "Employee_Job_Title", "Company_Name", 
             "Employee_City", "Employee_Country", "Employment_Status", 
             "Employee_Salary", "Employee_Rating", "Employee_Rating_New"]

df = df.loc[:,new_order]
df.head()
# Out:
#   First_name Last_name                       Employee_Job_Title
# 0    SPENCER    ADKINS                          Equities trader  \
# 1      JULIE    MORTON  Diplomatic Services operational officer
# 2    MATTHEW      HALL               Regulatory affairs officer
# 3       BRAD     SCOTT                      Production engineer
# 4    THERESA     OWENS                      Production engineer
#
#                    Company_Name      Employee_City       Employee_Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_Status  Employee_Salary  Employee_Rating  Employee_Rating_New
# 0         Full Time           321520              3.9                  4.8
# 1         Full Time           589090              4.3                  5.6
# 2         Full Time           630890              3.1                  3.2
# 3         Full Time           116400              3.1                  3.2
# 4         Full Time           523499              4.8                  6.6

# %% [markdown]
# ### 125. Compute the cosine similarity between the series 'Employee_Rating' and 'Employee_Rating_New'

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

cosine_similarity(
    df["Employee_Rating"].to_numpy().reshape(1,-1), 
    df["Employee_Rating_New"].to_numpy().reshape(1, -1)
)
# Out:
# array([[0.97924279]])

# %% [markdown]
# ### 126. Rename the columns and store to a new DataFrame 'df_renamed':

# %% [markdown]
# 1. Employee_Rating -> Rating
# 2. Employee_Country -> Country
# 3. Employee_Salary -> Salary
# 4. Employee_Rating_New -> Rating_New
# 5. Employment_Status -> Employment_type
# 6. Employment_City -> City

# %%
df_renamed = df.rename(columns={"Employee_Rating":"Rating","Employee_Country" : "Country","Employee_Salary" : "Salary",
                        "Employee_Rating_New" : "Rating_New", "Employment_Status" : "Employment_type",
                        "Employee_City" : "City"})

df_renamed.head()
# Out:
#   First_name Last_name                       Employee_Job_Title
# 0    SPENCER    ADKINS                          Equities trader  \
# 1      JULIE    MORTON  Diplomatic Services operational officer
# 2    MATTHEW      HALL               Regulatory affairs officer
# 3       BRAD     SCOTT                      Production engineer
# 4    THERESA     OWENS                      Production engineer
#
#                    Company_Name               City                Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_type  Salary  Rating  Rating_New
# 0       Full Time  321520     3.9         4.8
# 1       Full Time  589090     4.3         5.6
# 2       Full Time  630890     3.1         3.2
# 3       Full Time  116400     3.1         3.2
# 4       Full Time  523499     4.8         6.6

# %% [markdown]
# ### 127. Rename the columns (inplace):

# %% [markdown]
# 1. Employee_Rating -> Rating
# 2. Employee_Country -> Country
# 3. Employee_Salary -> Salary
# 4. Employee_Rating_New -> Rating_New
# 5. Employment_Status -> Employment_type
# 6. Employment_City -> City

# %%
df.rename(columns={"Employee_Rating":"Rating","Employee_Country" : "Country","Employee_Salary" : "Salary",
                        "Employee_Rating_New" : "Rating_New", "Employment_Status" : "Employment_type",
                        "Employee_City" : "City"},inplace=True)

df.head()
# Out:
#   First_name Last_name                       Employee_Job_Title
# 0    SPENCER    ADKINS                          Equities trader  \
# 1      JULIE    MORTON  Diplomatic Services operational officer
# 2    MATTHEW      HALL               Regulatory affairs officer
# 3       BRAD     SCOTT                      Production engineer
# 4    THERESA     OWENS                      Production engineer
#
#                    Company_Name               City                Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_type  Salary  Rating  Rating_New
# 0       Full Time  321520     3.9         4.8
# 1       Full Time  589090     4.3         5.6
# 2       Full Time  630890     3.1         3.2
# 3       Full Time  116400     3.1         3.2
# 4       Full Time  523499     4.8         6.6

# %% [markdown]
# ### 128. Count the number of NaN values in each column

# %%
df.isnull().sum()
# Out:
# First_name            0
# Last_name             0
# Employee_Job_Title    0
# Company_Name          0
# City                  0
# Country               0
# Employment_type       0
# Salary                0
# Rating                0
# Rating_New            0
# dtype: int64

# %% [markdown]
# ### 129. Write a function that takes the employee_salary and returns:

# %% [markdown]
# 1. "High" if the salary is >= 600000
# 2. "Medium" if the salary is > 300000 and < 600000
# 3. "Low" otherwise.
#
# Hint: Use the apply() method.
#
# **Store the returned series to a new column 'Salary_category'.**

# %% [markdown]
# ### 130. Print the count distribution of the 'Salary_category' column.

# %%
def salary(x):
    if x>=600000:
        return "High"
    elif x>300000 and x<600000:
        return "Medium"
    else:
        return "Low"

df["Salary_Category"] = df["Salary"].apply(lambda x : salary(x))

df.head()
# Out:
#   First_name Last_name                       Employee_Job_Title
# 0    SPENCER    ADKINS                          Equities trader  \
# 1      JULIE    MORTON  Diplomatic Services operational officer
# 2    MATTHEW      HALL               Regulatory affairs officer
# 3       BRAD     SCOTT                      Production engineer
# 4    THERESA     OWENS                      Production engineer
#
#                    Company_Name               City                Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_type  Salary  Rating  Rating_New Salary_Category
# 0       Full Time  321520     3.9         4.8          Medium
# 1       Full Time  589090     4.3         5.6          Medium
# 2       Full Time  630890     3.1         3.2            High
# 3       Full Time  116400     3.1         3.2             Low
# 4       Full Time  523499     4.8         6.6          Medium

# %% [markdown]
# ### 131.  Map every Company_Name to a unique integer value. Name the new column "Company_ID".

# %% [markdown]
# For instance, if the data has 5 companies, "Company A" -> 1, "Company B" -> 2, "Company C" -> 3, "Company D" -> 4, "Company E" -> 5.

# %%
d = {company : idx for idx, company in enumerate(df.Company_Name.unique(), start=1)}
df["Company_ID"] = df["Company_Name"].apply(lambda x : d.get(x))

df.head()
# Out:
#   First_name Last_name                       Employee_Job_Title
# 0    SPENCER    ADKINS                          Equities trader  \
# 1      JULIE    MORTON  Diplomatic Services operational officer
# 2    MATTHEW      HALL               Regulatory affairs officer
# 3       BRAD     SCOTT                      Production engineer
# 4    THERESA     OWENS                      Production engineer
#
#                    Company_Name               City                Country
# 0                James and Sons     New Russellton  Palestinian Territory  \
# 1                 Nichols-James  North Melissafurt       Marshall Islands
# 2                     Scott Inc           Wardfort               Anguilla
# 3  Johnston, Fleming and Tanner     West Jamesview   Syrian Arab Republic
# 4      Baker, Allen and Edwards          Whiteside               Dominica
#
#   Employment_type  Salary  Rating  Rating_New Salary_Category  Company_ID
# 0       Full Time  321520     3.9         4.8          Medium           1
# 1       Full Time  589090     4.3         5.6          Medium           2
# 2       Full Time  630890     3.1         3.2            High           3
# 3       Full Time  116400     3.1         3.2             Low           4
# 4       Full Time  523499     4.8         6.6          Medium           5

# %% [markdown]
# ### 132. Generate one-hot lables for the 'Employment_type' column. You don't have to add this as a column to the DataFrame.

# %%
onehot = pd.get_dummies(df["Employment_type"],dtype=int)
onehot
# Out:
#         Full Time  Intern
# 0               1       0
# 1               1       0
# 2               1       0
# 3               1       0
# 4               1       0
# ...           ...     ...
# 299996          0       1
# 299997          1       0
# 299998          1       0
# 299999          0       1
# 300000          1       0
#
# [300001 rows x 2 columns]

# %% [markdown]
# ### 133. Print the number of rows where 'City' belongs to the following list of cities.

# %% [markdown]
# Use the isin() method.

# %%
city_filter_list = ["New Russellton", "Whiteside", "Kristaburgh"]

row_count = df.loc[df["City"].isin(city_filter_list)].shape[0]

print(row_count)
# Out:
# 90054

# %% [markdown]
# ### 134. Print the name of the person with the 10th largest salary.

# %%
df.nlargest(10,"Salary").iloc[9] #["First_name"]
# Out:
# First_name                               MEGAN
# Last_name                             PETERSEN
# Employee_Job_Title         Retail merchandiser
# Company_Name          Baker, Allen and Edwards
# City                          New Cindychester
# Country                                Uruguay
# Employment_type                      Full Time
# Salary                                  999950
# Rating                                     4.9
# Rating_New                                 6.8
# Salary_Category                           High
# Company_ID                                   5
# Name: 241830, dtype: object

# %% [markdown]
# ### 135. Print the name of the person with the 10th largest salary. If there are multiple people with the same salary, print all names.

# %%
# Get the unique sorted salaries in descending order
unique_salaries = df["Salary"].drop_duplicates().sort_values(ascending=False)

# Get the 10th unique largest salary
tenth_largest_salary = unique_salaries.iloc[9]

# Find the person with this 10th largest salary
df[df["Salary"] == tenth_largest_salary]
# Out:
#        First_name Last_name Employee_Job_Title                Company_Name
# 205553    ADRIANA    GUZMAN    Patent examiner  Wallace, Smith and Shepard  \
#
#                 City   Country Employment_type  Salary  Rating  Rating_New
# 205553  Ricardomouth  Maldives       Full Time  999890     1.7         1.5  \
#
#        Salary_Category  Company_ID
# 205553            High          14

# %% [markdown]
# ### 136. Print a cross tabulation of Company Name and Employment Type.

# %%
pd.crosstab(df["Company_Name"], df["Employment_type"])
# Out:
# Employment_type                 Full Time  Intern
# Company_Name
# Andrade LLC                         15964    4019
# Baker, Allen and Edwards            16118    3966
# Bullock-Carrillo                    16135    3928
# Campos, Reynolds and Mccormick      15930    3997
# James and Sons                      15888    3980
# Johnston, Fleming and Tanner        15832    3979
# Marshall-Holloway                   15871    3988
# Matthews Inc                        16082    4001
# Nelson-Li                           16027    4105
# Nichols-James                       15872    4039
# Scott Inc                           16397    3994
# Taylor-Ramos                        16086    4036
# Thomas-Spencer                      16037    4105
# Wallace, Smith and Shepard          15467    3897
# White, Mcclain and Cobb             16305    3956

# %% [markdown]
# ### 137. Print the standard deviation of the Salary column.

# %%
df["Salary"].std()
# Out:
# 288361.9787166691

# %% [markdown]
# ### 138. Iterates over the DataFrame's first five rows and print the Company Name

# %% [markdown]
# Note: You have to write a for loop here explicitly and iterate.

# %%
for x in df.iterrows():
    if x[0]==5:
        break
    print(x[1]["Company_Name"])

# or
# for company in df.iloc[:5]["Company_Name"]:
#     print(company)
# Out:
# James and Sons
# Nichols-James
# Scott Inc
# Johnston, Fleming and Tanner
# Baker, Allen and Edwards

# %% [markdown]
# ### 139. Select the last row corresponding to every City in the dataframe

# %%
df.groupby("City").last().reset_index()
# Out:
#                 City First_name  Last_name
# 0         Aliciafort    MICHELE     BUTLER  \
# 1        Kristaburgh   JENNIFER    NAVARRO
# 2   New Cindychester       LYNN     WILSON
# 3     New Russellton      KAREN    DELGADO
# 4  North Melissafurt      NANCY       NEAL
# 5       Ricardomouth  ALEXANDER    KAUFMAN
# 6           Wardfort      CHRIS     ANDERS
# 7     West Jamesview  ELIZABETH    PERKINS
# 8       Whitakerbury    LINDSEY      KEITH
# 9          Whiteside    WILLIAM  RODRIGUEZ
#
#                         Employee_Job_Title                  Company_Name
# 0                            Administrator  Johnston, Fleming and Tanner  \
# 1             Investment banker, corporate  Johnston, Fleming and Tanner
# 2                            Administrator                 Nichols-James
# 3                                  Actuary                James and Sons
# 4                              Optometrist              Bullock-Carrillo
# 5  Diplomatic Services operational officer  Johnston, Fleming and Tanner
# 6                      Production engineer                     Scott Inc
# 7        Sales promotion account executive             Marshall-Holloway
# 8                                     Make                 Nichols-James
# 9                               Ergonomist                     Scott Inc
#
#           Country Employment_type  Salary  Rating  Rating_New Salary_Category
# 0            Cuba          Intern  949580     2.6         2.2            High  \
# 1           Nauru       Full Time  472090     4.3         5.6          Medium
# 2         Bolivia       Full Time  802830     0.6         1.5            High
# 3  United Kingdom          Intern  575770     3.3         3.6          Medium
# 4           Samoa          Intern   99670     3.3         3.6             Low
# 5           Congo       Full Time  729070     1.0         1.5            High
# 6        Anguilla       Full Time  343930     3.3         3.6          Medium
# 7       Sri Lanka       Full Time  723780     3.4         3.8            High
# 8  Western Sahara       Full Time  257240     2.4         1.8             Low
# 9     New Zealand       Full Time  214400     1.5         1.5             Low
#
#    Company_ID
# 0           4
# 1           4
# 2           2
# 3           1
# 4          12
# 5           4
# 6           3
# 7          13
# 8           2
# 9           3

# %% [markdown]
# ### 140. Sort the dataframe on Employee salary column (inplace).

# %%
df.sort_values(by=["Salary"],inplace=True)
df.head()
# Out:
#        First_name  Last_name
# 205070   COURTNEY  SINGLETON  \
# 54531     KRISTEN    VASQUEZ
# 229395      GRACE      SMITH
# 185700    VANESSA         WU
# 226792      PENNY       MEZA
#
#                                        Employee_Job_Title
# 205070                       Garment/textile technologist  \
# 54531   Armed forces logistics/support/administrative ...
# 229395                          Trading standards officer
# 185700                                    Patent examiner
# 226792                          Trading standards officer
#
#                           Company_Name               City
# 205070         White, Mcclain and Cobb   New Cindychester  \
# 54531          White, Mcclain and Cobb           Wardfort
# 229395    Johnston, Fleming and Tanner     West Jamesview
# 185700  Campos, Reynolds and Mccormick  North Melissafurt
# 226792      Wallace, Smith and Shepard           Wardfort
#
#                        Country Employment_type  Salary  Rating  Rating_New
# 205070                Ethiopia       Full Time       0     2.8         2.6  \
# 54531                  Bermuda       Full Time       0     3.4         3.8
# 229395  Libyan Arab Jamahiriya          Intern      10     1.1         1.5
# 185700                  Zambia       Full Time      10     1.3         1.5
# 226792                 Albania       Full Time      10     0.7         1.5
#
#        Salary_Category  Company_ID
# 205070             Low          10
# 54531              Low          10
# 229395             Low           4
# 185700             Low           9
# 226792             Low          14

# %% [markdown]
# ### 141. The task above has distorted the indexing. Reset the index inplace and drop the current index.

# %%
df.reset_index(inplace=True)

df.head()
# Out:
#     index First_name  Last_name
# 0  205070   COURTNEY  SINGLETON  \
# 1   54531    KRISTEN    VASQUEZ
# 2  229395      GRACE      SMITH
# 3  185700    VANESSA         WU
# 4  226792      PENNY       MEZA
#
#                                   Employee_Job_Title
# 0                       Garment/textile technologist  \
# 1  Armed forces logistics/support/administrative ...
# 2                          Trading standards officer
# 3                                    Patent examiner
# 4                          Trading standards officer
#
#                      Company_Name               City                 Country
# 0         White, Mcclain and Cobb   New Cindychester                Ethiopia  \
# 1         White, Mcclain and Cobb           Wardfort                 Bermuda
# 2    Johnston, Fleming and Tanner     West Jamesview  Libyan Arab Jamahiriya
# 3  Campos, Reynolds and Mccormick  North Melissafurt                  Zambia
# 4      Wallace, Smith and Shepard           Wardfort                 Albania
#
#   Employment_type  Salary  Rating  Rating_New Salary_Category  Company_ID
# 0       Full Time       0     2.8         2.6             Low          10
# 1       Full Time       0     3.4         3.8             Low          10
# 2          Intern      10     1.1         1.5             Low           4
# 3       Full Time      10     1.3         1.5             Low           9
# 4       Full Time      10     0.7         1.5             Low          14

# %%
df.drop(columns=["index"],inplace=True)
df.head()
# Out:
#   First_name  Last_name                                 Employee_Job_Title
# 0   COURTNEY  SINGLETON                       Garment/textile technologist  \
# 1    KRISTEN    VASQUEZ  Armed forces logistics/support/administrative ...
# 2      GRACE      SMITH                          Trading standards officer
# 3    VANESSA         WU                                    Patent examiner
# 4      PENNY       MEZA                          Trading standards officer
#
#                      Company_Name               City                 Country
# 0         White, Mcclain and Cobb   New Cindychester                Ethiopia  \
# 1         White, Mcclain and Cobb           Wardfort                 Bermuda
# 2    Johnston, Fleming and Tanner     West Jamesview  Libyan Arab Jamahiriya
# 3  Campos, Reynolds and Mccormick  North Melissafurt                  Zambia
# 4      Wallace, Smith and Shepard           Wardfort                 Albania
#
#   Employment_type  Salary  Rating  Rating_New Salary_Category  Company_ID
# 0       Full Time       0     2.8         2.6             Low          10
# 1       Full Time       0     3.4         3.8             Low          10
# 2          Intern      10     1.1         1.5             Low           4
# 3       Full Time      10     1.3         1.5             Low           9
# 4       Full Time      10     0.7         1.5             Low          14

# %% [markdown]
# ### 142. Now check whether the Salary column is monotonically increasing or not.

# %%
df["Salary"].is_monotonic_increasing
# Out:
# True

# %% [markdown]
# ### 143-145. Print the 25th, 50th and 75th percentile of the Salary column

# %%
print(df["Salary"].quantile(0.25))
print(df["Salary"].quantile())
print(df["Salary"].quantile(0.75))
# Out:
# 250000.0
# 500780.0
# 749710.0

# %% [markdown]
# ### 146. Plot a scatter plot between the Salary column and Rating.

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Salary"],df["Rating"])
plt.xlabel('Salary')
plt.ylabel('Rating')
plt.title('Scatter Plot of Salary vs Rating')
plt.show()

# %% [markdown]
# ### 147. Distribute the Salary column in 10 equal sized bins.

# %%
pd.cut(df["Salary"],bins=10,include_lowest=True)
# Out:
# 0          (-999.991, 99999.0]
# 1          (-999.991, 99999.0]
# 2          (-999.991, 99999.0]
# 3          (-999.991, 99999.0]
# 4          (-999.991, 99999.0]
#                   ...
# 299996    (899991.0, 999990.0]
# 299997    (899991.0, 999990.0]
# 299998    (899991.0, 999990.0]
# 299999    (899991.0, 999990.0]
# 300000    (899991.0, 999990.0]
# Name: Salary, Length: 300001, dtype: category
# Categories (10, interval[float64, right]): [(-999.991, 99999.0] < (99999.0, 199998.0] < (199998.0, 299997.0] < (299997.0, 399996.0] ... (599994.0, 699993.0] < (699993.0, 799992.0] < (799992.0, 899991.0] < (899991.0, 999990.0]]

# %% [markdown]
# ### 148. Convert the Salary column to numpy array

# %%
ans = df["Salary"].to_numpy()
ans
# Out:
# array([     0,      0,     10, ..., 999980, 999980, 999990], dtype=int64)

# %% [markdown]
# ### 149. Convert the Rating column to numpy array

# %%
ans2 = df["Rating"].to_numpy()
ans2
# Out:
# array([2.8, 3.4, 1.1, ..., 2.6, 2.4, 4. ])

# %% [markdown]
# ### 150. Compute the cosine similarity between the numpy arrays created in 148 and 149.

# %%
cosine_similarity(ans.reshape(1,-1),ans2.reshape(1,-1))
# Out:
# array([[0.75040542]])

# %% [markdown]
# Great job solving this notebook. Go to Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb)
